# %%
# %matplotlib ipympl
# % matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import datetime
import glob
import netCDF4
import xarray as xr
import pandas as pd
import seaborn as sns
import os
#plt.style.use('seaborn')

from scipy import stats
from scipy.fft import fft, fftfreq, fftshift

# %% [markdown]
# #### Data Opening Functions

# %%
def data_opening_w_stripe(stripe, d):
    dsf_raw = xr.open_dataset(d,engine = 'netcdf4')  

    # FOR FUV A SWP
    if 'ICON_L1_FUVA_SWP_Center_Times' in dsf_raw.variables.keys():
        dsf = dsf_raw[['ICON_L1_FUVA_SWP_Center_Times','ICON_L1_FUVA_SWP_PROF_'+str(stripe)]]
        # Convert times to something Python and xarray can understand, and reindex the dataset by time 
        t = pd.to_datetime(dsf.ICON_L1_FUVA_SWP_Center_Times.values)
        dsf['time'] = (['Epoch'], t)
        dsf = dsf.swap_dims({'Epoch':'time'})
        dsf = dsf.rename({'Rows':'row'})
        # Rename and drop useless variables
        dsf['I_1356'] = dsf['ICON_L1_FUVA_SWP_PROF_'+str(stripe)]
        dsf = dsf.drop(['ICON_L1_FUVA_SWP_PROF_'+str(stripe),'ICON_L1_FUVA_SWP_Center_Times','Epoch'])
    
    # FOR FUV B LWP
    elif 'ICON_L1_FUVB_LWP_Center_Times' in dsf_raw.variables.keys():
        dsf = dsf_raw[['ICON_L1_FUVB_LWP_Center_Times','ICON_L1_FUVB_LWP_PROF_'+str(stripe)]]
        # Convert times to something Python and xarray can understand, and reindex the dataset by time 
        t = pd.to_datetime(dsf.ICON_L1_FUVB_LWP_Center_Times.values)
        dsf['time'] = (['Epoch'], t)
        dsf = dsf.swap_dims({'Epoch':'time'})
        dsf = dsf.rename({'Rows':'row'})
        #  Rename and drop useless variables
        dsf['N2'] = dsf['ICON_L1_FUVB_LWP_PROF_'+str(stripe)]
        dsf = dsf.drop(['ICON_L1_FUVB_LWP_PROF_'+str(stripe),'ICON_L1_FUVB_LWP_Center_Times','Epoch'])    
      
    return dsf

# %% [markdown]
# #### Orbit Separation Functions

# %%
def orbits_finder(df):
    from scipy.signal import find_peaks
    data = df.I_1356.mean(dim = 'row')
    data_np = data.to_numpy()
    np.shape(data)

    max_data = max(data_np)
    time_diff = pd.to_timedelta('75 m')
    half_time_diff = pd.to_timedelta('50 m')

    indices = find_peaks(data, height = max_data * (4/6)) 

    indexes = indices[0]
    indexes 

    final_indexes = []

    for i in range(0,len(indexes)-1):
        if len(indexes) > 15:
            if indexes[i+1] - indexes[i] < 200:
                pass
            else:
                final_indexes.append(indexes[i])
        else:
            final_indexes.append(indexes[i])
    final_indexes.append(indexes[-1])
    
    times_np = df.time.to_numpy()
    times_dt = pd.to_datetime(times_np)
    
    all_orbits = []
    for i in final_indexes:
        start_time = times_dt[i] - half_time_diff
        end_time = start_time + time_diff
        df_orbit = df.sel(time=slice(start_time, end_time))
        all_orbits.append(df_orbit)
        
    return all_orbits

# %%
def single_orb(orbit_arr,n):
    orb = orbit_arr[n].mean(dim = 'row')
    t = orb.time
    
    if 'I_1356' in orb.variables.keys():
        val = orb.I_1356
    elif 'N2' in orb.variables.keys():
        val = orb.N2
        
    return(t, val)

# %% [markdown]
# #### Wavelength Finder

# %%
def wavelength_plots(swp_data,day,orbit_num,nsamples):
    
    # Remove ~3.5 minute (17-sample) rolling mean (FUV samples @ 12 sec)
    swp_data['I_1356_filt'] = swp_data['I_1356'] - swp_data['I_1356'].rolling(time=nsamples, center=True).mean() 
    
    #SLICE OUT END FEATURES
    s = len(swp_data["I_1356_filt"])
    lim_val = int(s/6)
    s_lim = int(1.5 * lim_val)

    time_start = swp_data['time'].isel(time=s_lim).values
    time_end =  swp_data['time'].isel(time=lim_val * 5).values
    swp_data = swp_data.sel(time=slice(time_start, time_end))
    
    #SLICE ROWS
    swp_sel_rows = swp_data.isel(row=slice(0, 126))
    
    swp_row_means = swp_sel_rows.mean(dim = 'row')
    swp_line_data = swp_row_means.dropna(dim = 'time')
    swp_t = swp_line_data.time

    # FT
    x_data = swp_t 
    y_data = swp_line_data['I_1356_filt']

    x_data = x_data.values.astype('float64')
    y_data = y_data.values
    y_data = y_data- np.mean(y_data)
    
    #print(np.mean(y_data))

    ft_data = fft(y_data)
    freqs = fftfreq(len(x_data), (x_data[0]- x_data[1]) * 1e-9)
    
    #FFT Shifted
    shifted_transformed = fftshift(ft_data)
    shifted_freqs = fftshift(freqs)

    # Scaled
    #scaled = shifted_freqs * 12*7.5
    
    
    # INITIALIZE PLOTS
    #(fig, ((ax1,ax2),(ax3,ax4))) = plt.subplots(2, 2, figsize = (15,8))
    (fig, (ax1,ax2,ax3)) = plt.subplots(3, 1, figsize = (10,15))

    # FUV 1- SWP RAW
    vm_1 = 60 
    pcm_1 = ax1.pcolormesh(pd.to_datetime(swp_sel_rows.time.values), swp_sel_rows.row, swp_sel_rows.I_1356_filt.T, cmap='plasma', vmin=-vm_1, vmax=vm_1)
    ax1.set_ylabel('Row')
    fig.colorbar(pcm_1, ax = ax1, label='R')
    ax1.set_title(f'FUV SWP 1356 brightness on {day} (Orbit {orbit_num})\n Samples: {nsamples}')  

    
    # Line Plot
    ax2.set_title(f'FUV brightness on {day} (Orbit {orbit_num})')
    ax2.plot(swp_t,swp_line_data['I_1356_filt'],'b',label = 'SWP 1356 Emission')
    ax2.set_ylabel ("FUV Brightness")
    ax2.legend()

    
    # Find Peak
    from scipy.signal import find_peaks
    x = shifted_freqs
    y = np.abs(shifted_transformed)
    max_data = max(y)

    indices = find_peaks(y, height = max_data * 1/2) 

    indexes = indices[0]

    times = []
    vals_at_times = []
    for i in indexes: 
        times.append(x[i])
        vals_at_times.append(y[i])
    
    peak_times = []
    peak_vals = []
    
    for i in range(0,len(times)):
        if times[i] >= 0.005 or times[i] <= -0.005:
            peak_times.append(times[i])
            peak_vals.append(vals_at_times[i])
        
    # FT Plot w Peaks
    ax3.plot(shifted_freqs, np.abs(shifted_transformed))
    ax3.set_title('Fourier Transform for Orbit '+str(orbit_num)+' \n' + str(day) + ' for SWP P0')
    
    for i in range(0,len(peak_times)):
        ax3.plot(peak_times[i],peak_vals[i],'ro', markersize = 5)
    ax3.set_xlabel('Frequency (Hz)')
    ax3.set_ylabel('Amplitude')
       
    
    # Freq to Wavelength
    dist_peak = []
    
    for f in peak_times:
        if f > 0: # just taking positive so I get one value
            dist_peak.append(1/f * 7.5)

    plt.tight_layout()

    return dist_peak

    #fig_name = f'corr_fuv_lineplot_{day}_orbit{orbit_num}'
    #plt.savefig(fig_name)

# %%
def wavelength_finder(swp_data,day,orbit_num,nsamples):
    
    # Remove ~3.5 minute (17-sample) rolling mean (FUV samples @ 12 sec)
    swp_data['I_1356_filt'] = swp_data['I_1356'] - swp_data['I_1356'].rolling(time=nsamples, center=True).mean() 
    
    #SLICE OUT END FEATURES
    s = len(swp_data["I_1356_filt"])
    lim_val = int(s/6)
    s_lim = int(1.5 * lim_val)

    time_start = swp_data['time'].isel(time=s_lim).values
    time_end =  swp_data['time'].isel(time=lim_val * 5).values
    swp_data = swp_data.sel(time=slice(time_start, time_end))
    
    #SLICE ROWS
    swp_sel_rows = swp_data.isel(row=slice(0, 126))
    
    swp_row_means = swp_sel_rows.mean(dim = 'row')
    swp_line_data = swp_row_means.dropna(dim = 'time')
    swp_t = swp_line_data.time

    # FT
    x_data = swp_t 
    y_data = swp_line_data['I_1356_filt']

    x_data = x_data.values.astype('float64')
    y_data = y_data.values
    y_data = y_data- np.mean(y_data)
    
    #print(np.mean(y_data))
    ft_data = fft(y_data)
    freqs = fftfreq(len(x_data), (x_data[0]- x_data[1]) * 1e-9)
    
    #FFT Shifted
    shifted_transformed = fftshift(ft_data)
    shifted_freqs = fftshift(freqs)

    # Find Peak
    from scipy.signal import find_peaks
    x = shifted_freqs
    y = np.abs(shifted_transformed)
    max_data = max(y)

    indices = find_peaks(y, height = max_data * 1/2) 

    indexes = indices[0]

    times = []
    vals_at_times = []
    for i in indexes: 
        times.append(x[i])
        vals_at_times.append(y[i])
    
    peak_times = []
    peak_vals = []

    
    for i in range(0,len(times)):
        if times[i] >= 0.005 or times[i] <= -0.005:
            peak_times.append(times[i])
            peak_vals.append(vals_at_times[i])

    
    # Freq to Wavelength
    dist_peak = []
    
    for f in peak_times:
        if f > 0: # just taking positive so I get one value
            dist_peak.append(1/f * 7.5)

    return dist_peak,day,orbit_num

# %%
def dominant_wavelength_finder(swp_data,day,orbit_num,nsamples):
    
    # Remove ~3.5 minute (17-sample) rolling mean (FUV samples @ 12 sec)
    swp_data['I_1356_filt'] = swp_data['I_1356'] - swp_data['I_1356'].rolling(time=nsamples, center=True).mean() 
    
    #SLICE OUT END FEATURES
    s = len(swp_data["I_1356_filt"])
    lim_val = int(s/6)
    s_lim = int(1.5 * lim_val)

    time_start = swp_data['time'].isel(time=s_lim).values
    time_end =  swp_data['time'].isel(time=lim_val * 5).values
    swp_data = swp_data.sel(time=slice(time_start, time_end))
    
    #SLICE ROWS
    swp_sel_rows = swp_data.isel(row=slice(0, 126))
    
    swp_row_means = swp_sel_rows.mean(dim = 'row')
    swp_line_data = swp_row_means.dropna(dim = 'time')
    swp_t = swp_line_data.time

    # FT
    x_data = swp_t 
    y_data = swp_line_data['I_1356_filt']

    x_data = x_data.values.astype('float64')
    y_data = y_data.values
    y_data = y_data- np.mean(y_data)
    
    #print(np.mean(y_data))
    ft_data = fft(y_data)
    freqs = fftfreq(len(x_data), (x_data[0]- x_data[1]) * 1e-9)
    
    #FFT Shifted
    shifted_transformed = fftshift(ft_data)
    shifted_freqs = fftshift(freqs)

    # Find Peak
    x = shifted_freqs
    y = np.abs(shifted_transformed)
    
    limited_indexes = []
    
    lim = 0.005 * 17/nsamples

    for i in range(0,len(x)):
        if x[i] >= lim or x[i] <= -lim :
            limited_indexes.append(i)
    
    times = []
    vals_at_times = []
    
    for j in limited_indexes:
        times.append(x[j])
        vals_at_times.append(y[j])
           
    max_index_pos = 0
    y_max_pos = 0

    for i in range(0,len(times)):
        if times[i] > 0 and vals_at_times[i] > y_max_pos:
            y_max_pos = vals_at_times[i]
            max_index_pos = i
        
    # Freq to Wavelength
    dist_peak = (1/x[max_index_pos] * 7.5)

    return dist_peak,day,orbit_num

# %% [markdown]
# #### Load in Data- ALL PEAKS

# %%
# Define the directory path (change this to your directory)
directory_path = "/Users/pkoll/ICON_FUV"

# Use glob to find all CSV files in the directory
file_pattern = os.path.join(directory_path, '*.nc')  
files = glob.glob(file_pattern)

all_dists = []
day_outliers = []

# Check if we found more than 1 file
if len(files) > 1:
    print(f"Found {len(files)} files. Processing...")

    # Iterate over the files and process each one
    for file_path in files:
        try:
           # print(file_path)
            file_name = os.path.basename(file_path)
           # print(file_name)
            
            swp_p0 = data_opening_w_stripe('P0',file_name)             
            
            # Day Name
            parts = file_name.split('_')
            day = parts[4]

            print("All Data Opened for", day)

            for orbit in range(0,15):
                swp_data = orbits_finder(swp_p0)[orbit]
                result = wavelength_finder(swp_data,day,orbit,17)
                dist_vals = result[0]
                day_val = result[1]
                orbit_val = result[2]
                
                if len(dist_vals) > 1:
                    day_outliers.append(str(day_val) + ' '+ str(orbit_val))
    
                all_dists.append(dist_vals)
            
            print(f' DONE: Entirely Processed {day}')
        
        except Exception as e:
            print(f"Error processing {file_path}: {e}")

else:
    print(f"Found only {len(files)} files. Not enough files to process.")
# Out:
# Found 132 files. Processing...
# Error processing /Users/pkoll/ICON_FUV\ICON_L0P_FUV_Ancillary_2020-09-24_v03r002.NC: cannot access local variable 'dsf' where it is not associated with a value
# All Data Opened for 2019-11-16
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_LWP_2019-11-16_v05r001.NC: 'Dataset' object has no attribute 'I_1356'
# All Data Opened for 2020-01-01
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_LWP_2020-01-01_v05r000.NC: 'Dataset' object has no attribute 'I_1356'
# All Data Opened for 2020-01-02
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_LWP_2020-01-02_v05r001.NC: 'Dataset' object has no attribute 'I_1356'
# All Data Opened for 2020-03-22
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_LWP_2020-03-22_v05r000.NC: 'Dataset' object has no attribute 'I_1356'
# All Data Opened for 2020-05-10
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_LWP_2020-05-10_v05r000.NC: 'Dataset' object has no attribute 'I_1356'
# All Data Opened for 2020-01-01
#  DONE: Entirely Processed 2020-01-01
# All Data Opened for 2020-01-02
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-01-02_v05r001.NC: list index out of range
# All Data Opened for 2020-01-07
#  DONE: Entirely Processed 2020-01-07
# All Data Opened for 2020-01-11
#  DONE: Entirely Processed 2020-01-11
# All Data Opened for 2020-01-15
#  DONE: Entirely Processed 2020-01-15
# All Data Opened for 2020-01-19
#  DONE: Entirely Processed 2020-01-19
# All Data Opened for 2020-01-23
#  DONE: Entirely Processed 2020-01-23
# All Data Opened for 2020-02-06
#  DONE: Entirely Processed 2020-02-06
# All Data Opened for 2020-02-08
#  DONE: Entirely Processed 2020-02-08
# All Data Opened for 2020-02-10
#  DONE: Entirely Processed 2020-02-10
# All Data Opened for 2020-02-12
#  DONE: Entirely Processed 2020-02-12
# All Data Opened for 2020-02-15
#  DONE: Entirely Processed 2020-02-15
# All Data Opened for 2020-02-17
#  DONE: Entirely Processed 2020-02-17
# All Data Opened for 2020-02-25
#  DONE: Entirely Processed 2020-02-25
# All Data Opened for 2020-02-28
#  DONE: Entirely Processed 2020-02-28
# All Data Opened for 2020-03-06
#  DONE: Entirely Processed 2020-03-06
# All Data Opened for 2020-03-11
#  DONE: Entirely Processed 2020-03-11
# All Data Opened for 2020-03-11
#  DONE: Entirely Processed 2020-03-11
# All Data Opened for 2020-03-15
#  DONE: Entirely Processed 2020-03-15
# All Data Opened for 2020-03-20
#  DONE: Entirely Processed 2020-03-20
# All Data Opened for 2020-03-22
#  DONE: Entirely Processed 2020-03-22
# All Data Opened for 2020-03-25
#  DONE: Entirely Processed 2020-03-25
# All Data Opened for 2020-03-27
#  DONE: Entirely Processed 2020-03-27
# All Data Opened for 2020-03-30
#  DONE: Entirely Processed 2020-03-30
# All Data Opened for 2020-03-30
#  DONE: Entirely Processed 2020-03-30
# All Data Opened for 2020-04-02
#  DONE: Entirely Processed 2020-04-02
# All Data Opened for 2020-04-04
#  DONE: Entirely Processed 2020-04-04
# All Data Opened for 2020-04-06
#  DONE: Entirely Processed 2020-04-06
# All Data Opened for 2020-04-08
#  DONE: Entirely Processed 2020-04-08
# All Data Opened for 2020-04-10
#  DONE: Entirely Processed 2020-04-10
# All Data Opened for 2020-04-13
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-04-13_v05r000.NC: list index out of range
# All Data Opened for 2020-04-15
#  DONE: Entirely Processed 2020-04-15
# All Data Opened for 2020-04-20
#  DONE: Entirely Processed 2020-04-20
# All Data Opened for 2020-04-20
#  DONE: Entirely Processed 2020-04-20
# All Data Opened for 2020-04-22
#  DONE: Entirely Processed 2020-04-22
# All Data Opened for 2020-04-24
#  DONE: Entirely Processed 2020-04-24
# All Data Opened for 2020-04-28
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-04-28_v05r000.NC: list index out of range
# All Data Opened for 2020-04-30
#  DONE: Entirely Processed 2020-04-30
# All Data Opened for 2020-05-01
#  DONE: Entirely Processed 2020-05-01
# All Data Opened for 2020-05-04
#  DONE: Entirely Processed 2020-05-04
# All Data Opened for 2020-05-06
#  DONE: Entirely Processed 2020-05-06
# All Data Opened for 2020-05-10
#  DONE: Entirely Processed 2020-05-10
# All Data Opened for 2020-05-12
#  DONE: Entirely Processed 2020-05-12
# All Data Opened for 2020-05-15
#  DONE: Entirely Processed 2020-05-15
# All Data Opened for 2020-05-22
#  DONE: Entirely Processed 2020-05-22
# All Data Opened for 2020-05-26
#  DONE: Entirely Processed 2020-05-26
# All Data Opened for 2020-05-29
#  DONE: Entirely Processed 2020-05-29
# All Data Opened for 2020-06-02
#  DONE: Entirely Processed 2020-06-02
# All Data Opened for 2020-06-05
#  DONE: Entirely Processed 2020-06-05
# All Data Opened for 2020-06-07
#  DONE: Entirely Processed 2020-06-07
# All Data Opened for 2020-06-10
#  DONE: Entirely Processed 2020-06-10
# All Data Opened for 2020-06-17
#  DONE: Entirely Processed 2020-06-17
# All Data Opened for 2020-06-20
#  DONE: Entirely Processed 2020-06-20
# All Data Opened for 2020-06-22
#  DONE: Entirely Processed 2020-06-22
# All Data Opened for 2020-06-25
#  DONE: Entirely Processed 2020-06-25
# All Data Opened for 2020-06-29
#  DONE: Entirely Processed 2020-06-29
# All Data Opened for 2020-07-02
#  DONE: Entirely Processed 2020-07-02
# All Data Opened for 2020-07-03
#  DONE: Entirely Processed 2020-07-03
# All Data Opened for 2020-07-05
#  DONE: Entirely Processed 2020-07-05
# All Data Opened for 2020-07-08
#  DONE: Entirely Processed 2020-07-08
# All Data Opened for 2020-07-11
#  DONE: Entirely Processed 2020-07-11
# All Data Opened for 2020-07-15
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-07-15_v05r000.NC: list index out of range
# All Data Opened for 2020-07-18
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-07-18_v05r000.NC: list index out of range
# All Data Opened for 2020-07-22
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-07-22_v05r000.NC: list index out of range
# All Data Opened for 2020-07-25
#  DONE: Entirely Processed 2020-07-25
# All Data Opened for 2020-07-29
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-07-29_v05r000.NC: list index out of range
# All Data Opened for 2020-08-02
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-08-02_v05r001.NC: list index out of range
# All Data Opened for 2020-08-12
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-08-12_v05r000.NC: list index out of range
# All Data Opened for 2020-08-15
#  DONE: Entirely Processed 2020-08-15
# All Data Opened for 2020-08-17
#  DONE: Entirely Processed 2020-08-17
# All Data Opened for 2020-08-19
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-08-19_v05r000.NC: list index out of range
# All Data Opened for 2020-08-21
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-08-21_v05r000.NC: list index out of range
# All Data Opened for 2020-08-24
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-08-24_v05r000.NC: list index out of range
# All Data Opened for 2020-08-26
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-08-26_v05r000.NC: list index out of range
# All Data Opened for 2020-08-28
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-08-28_v05r000.NC: list index out of range
# All Data Opened for 2020-09-01
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-01_v05r000.NC: list index out of range
# All Data Opened for 2020-09-03
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-03_v05r000.NC: list index out of range
# All Data Opened for 2020-09-05
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-05_v05r000.NC: list index out of range
# All Data Opened for 2020-09-07
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-07_v05r000.NC: list index out of range
# All Data Opened for 2020-09-11
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-11_v05r000.NC: list index out of range
# All Data Opened for 2020-09-13
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-13_v05r000.NC: list index out of range
# All Data Opened for 2020-09-16
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-16_v05r000.NC: list index out of range
# All Data Opened for 2020-09-18
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-18_v05r000.NC: list index out of range
# All Data Opened for 2020-09-20
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-20_v05r000.NC: list index out of range
# All Data Opened for 2020-09-23
#  DONE: Entirely Processed 2020-09-23
# All Data Opened for 2020-09-24
#  DONE: Entirely Processed 2020-09-24
# All Data Opened for 2020-09-25
#  DONE: Entirely Processed 2020-09-25
# All Data Opened for 2020-09-27
#  DONE: Entirely Processed 2020-09-27
# All Data Opened for 2020-10-01
#  DONE: Entirely Processed 2020-10-01
# All Data Opened for 2020-10-03
#  DONE: Entirely Processed 2020-10-03
# All Data Opened for 2020-10-05
#  DONE: Entirely Processed 2020-10-05
# All Data Opened for 2020-10-08
#  DONE: Entirely Processed 2020-10-08
# All Data Opened for 2020-10-10
#  DONE: Entirely Processed 2020-10-10
# All Data Opened for 2020-10-10
#  DONE: Entirely Processed 2020-10-10
# All Data Opened for 2020-10-13
#  DONE: Entirely Processed 2020-10-13
# All Data Opened for 2020-10-15
#  DONE: Entirely Processed 2020-10-15
# All Data Opened for 2020-10-17
#  DONE: Entirely Processed 2020-10-17
# All Data Opened for 2020-10-19
#  DONE: Entirely Processed 2020-10-19
# All Data Opened for 2020-10-21
#  DONE: Entirely Processed 2020-10-21
# All Data Opened for 2020-10-23
#  DONE: Entirely Processed 2020-10-23
# All Data Opened for 2020-10-25
#  DONE: Entirely Processed 2020-10-25
# All Data Opened for 2020-10-28
#  DONE: Entirely Processed 2020-10-28
# All Data Opened for 2020-10-31
#  DONE: Entirely Processed 2020-10-31
# All Data Opened for 2020-11-02
#  DONE: Entirely Processed 2020-11-02
# All Data Opened for 2020-11-04
#  DONE: Entirely Processed 2020-11-04
# All Data Opened for 2020-11-05
#  DONE: Entirely Processed 2020-11-05
# All Data Opened for 2020-11-10
#  DONE: Entirely Processed 2020-11-10
# All Data Opened for 2020-11-13
#  DONE: Entirely Processed 2020-11-13
# All Data Opened for 2020-11-17
#  DONE: Entirely Processed 2020-11-17
# All Data Opened for 2020-11-22
#  DONE: Entirely Processed 2020-11-22
# All Data Opened for 2020-11-25
#  DONE: Entirely Processed 2020-11-25
# All Data Opened for 2020-11-28
#  DONE: Entirely Processed 2020-11-28
# All Data Opened for 2020-11-30
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-11-30_v05r000 (1).NC: list index out of range
# All Data Opened for 2020-11-30
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-11-30_v05r000.NC: list index out of range
# All Data Opened for 2020-12-02
#  DONE: Entirely Processed 2020-12-02
# All Data Opened for 2020-12-05
#  DONE: Entirely Processed 2020-12-05
# All Data Opened for 2020-12-09
#  DONE: Entirely Processed 2020-12-09
# All Data Opened for 2020-12-13
#  DONE: Entirely Processed 2020-12-13
# All Data Opened for 2020-12-16
#  DONE: Entirely Processed 2020-12-16
# All Data Opened for 2020-12-18
#  DONE: Entirely Processed 2020-12-18
# All Data Opened for 2020-12-20
#  DONE: Entirely Processed 2020-12-20
# All Data Opened for 2020-12-22
#  DONE: Entirely Processed 2020-12-22
# All Data Opened for 2020-12-25
#  DONE: Entirely Processed 2020-12-25
# All Data Opened for 2020-12-27
#  DONE: Entirely Processed 2020-12-27
# All Data Opened for 2020-12-30
#  DONE: Entirely Processed 2020-12-30
# All Data Opened for 2020-12-31
#  DONE: Entirely Processed 2020-12-31

# %%
d = []
for list in all_dists:
    for i in list:
        d.append(i)

# %% [markdown]
# #### Histogram of Distances

# %%
plt.figure()
# Create histogram
plt.hist(d, bins = 50, edgecolor='black')

# Add titles and labels
plt.title('Distribution of Distances')
plt.xlabel('Distance Values (km)')
plt.ylabel('Frequency')
# Show
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Individual Orbit Checker

# %%
day_outliers
# Out:
# ['2020-01-01 1',
#  '2020-01-01 2',
#  '2020-01-01 3',
#  '2020-01-01 6',
#  '2020-01-01 7',
#  '2020-01-01 8',
#  '2020-01-02 3',
#  '2020-01-02 4',
#  '2020-01-02 5',
#  '2020-01-02 6',
#  '2020-01-02 8',
#  '2020-01-02 13',
#  '2020-01-07 9',
#  '2020-01-07 13',
#  '2020-01-07 14',
#  '2020-01-11 2',
#  '2020-01-11 9',
#  '2020-01-11 12',
#  '2020-01-11 13',
#  '2020-01-15 3',
#  '2020-01-15 4',
#  '2020-01-15 9',
#  '2020-01-15 10',
#  '2020-01-15 11',
#  '2020-01-15 12',
#  '2020-01-15 14',
#  '2020-01-19 0',
#  '2020-01-19 2',
#  '2020-01-19 3',
#  '2020-01-19 4',
#  '2020-01-19 9',
#  '2020-01-19 10',
#  '2020-01-19 11',
#  '2020-01-19 14',
#  '2020-01-23 1',
#  '2020-01-23 2',
#  '2020-01-23 3',
#  '2020-01-23 4',
#  '2020-01-23 5',
#  '2020-01-23 7',
#  '2020-01-23 10',
#  '2020-01-23 12',
#  '2020-01-23 13',
#  '2020-02-06 0',
#  '2020-02-06 1',
#  '2020-02-06 2',
#  '2020-02-06 3',
#  '2020-02-06 6',
#  '2020-02-06 7',
#  '2020-02-06 8',
#  '2020-02-06 9',
#  '2020-02-06 10',
#  '2020-02-06 11',
#  '2020-02-06 12',
#  '2020-02-06 13',
#  '2020-02-06 14',
#  '2020-02-08 1',
#  '2020-02-08 3',
#  '2020-02-08 5',
#  '2020-02-08 7',
#  '2020-02-08 9',
#  '2020-02-08 10',
#  '2020-02-08 12',
#  '2020-02-08 13',
#  '2020-02-10 0',
#  '2020-02-10 1',
#  '2020-02-10 3',
#  '2020-02-10 4',
#  '2020-02-10 6',
#  '2020-02-10 8',
#  '2020-02-10 9',
#  '2020-02-10 10',
#  '2020-02-10 11',
#  '2020-02-10 12',
#  '2020-02-10 14',
#  '2020-02-12 0',
#  '2020-02-12 1',
#  '2020-02-12 2',
#  '2020-02-12 3',
#  '2020-02-12 7',
#  '2020-02-12 9',
#  '2020-02-12 12',
#  '2020-02-12 13',
#  '2020-02-12 14',
#  '2020-02-15 0',
#  '2020-02-15 1',
#  '2020-02-15 2',
#  '2020-02-15 3',
#  '2020-02-15 5',
#  '2020-02-15 6',
#  '2020-02-15 7',
#  '2020-02-15 8',
#  '2020-02-15 12',
#  '2020-02-15 13',
#  '2020-02-15 14',
#  '2020-02-17 0',
#  '2020-02-17 1',
#  '2020-02-17 3',
#  '2020-02-17 4',
#  '2020-02-17 5',
#  '2020-02-17 6',
#  '2020-02-17 7',
#  '2020-02-17 8',
#  '2020-02-17 9',
#  '2020-02-17 11',
#  '2020-02-17 12',
#  '2020-02-17 13',
#  '2020-02-17 14',
#  '2020-02-25 0',
#  '2020-02-25 1',
#  '2020-02-25 2',
#  '2020-02-25 3',
#  '2020-02-25 4',
#  '2020-02-25 5',
#  '2020-02-25 6',
#  '2020-02-25 8',
#  '2020-02-25 9',
#  '2020-02-25 10',
#  '2020-02-25 12',
#  '2020-02-25 13',
#  '2020-02-28 0',
#  '2020-02-28 2',
#  '2020-02-28 3',
#  '2020-02-28 4',
#  '2020-02-28 5',
#  '2020-02-28 8',
#  '2020-02-28 9',
#  '2020-02-28 10',
#  '2020-02-28 12',
#  '2020-02-28 13',
#  '2020-02-28 14',
#  '2020-03-06 0',
#  '2020-03-06 3',
#  '2020-03-06 4',
#  '2020-03-06 6',
#  '2020-03-06 7',
#  '2020-03-06 8',
#  '2020-03-06 9',
#  '2020-03-06 12',
#  '2020-03-06 13',
#  '2020-03-11 0',
#  '2020-03-11 1',
#  '2020-03-11 3',
#  '2020-03-11 4',
#  '2020-03-11 5',
#  '2020-03-11 6',
#  '2020-03-11 7',
#  '2020-03-11 8',
#  '2020-03-11 9',
#  '2020-03-11 10',
#  '2020-03-11 0',
#  '2020-03-11 1',
#  '2020-03-11 3',
#  '2020-03-11 4',
#  '2020-03-11 5',
#  '2020-03-11 6',
#  '2020-03-11 7',
#  '2020-03-11 8',
#  '2020-03-11 9',
#  '2020-03-11 10',
#  '2020-03-15 1',
#  '2020-03-15 3',
#  '2020-03-15 4',
#  '2020-03-15 5',
#  '2020-03-15 6',
#  '2020-03-15 7',
#  '2020-03-15 8',
#  '2020-03-15 9',
#  '2020-03-15 10',
#  '2020-03-15 11',
#  '2020-03-15 12',
#  '2020-03-15 13',
#  '2020-03-20 1',
#  '2020-03-20 4',
#  '2020-03-20 6',
#  '2020-03-20 8',
#  '2020-03-20 12',
#  '2020-03-20 13',
#  '2020-03-20 14',
#  '2020-03-22 5',
#  '2020-03-22 7',
#  '2020-03-22 8',
#  '2020-03-22 9',
#  '2020-03-22 10',
#  '2020-03-22 11',
#  '2020-03-22 12',
#  '2020-03-22 13',
#  '2020-03-22 14',
#  '2020-03-25 0',
#  '2020-03-25 1',
#  '2020-03-25 2',
#  '2020-03-25 3',
#  '2020-03-25 5',
#  '2020-03-25 10',
#  '2020-03-25 11',
#  '2020-03-25 12',
#  '2020-03-25 13',
#  '2020-03-25 14',
#  '2020-03-27 0',
#  '2020-03-27 1',
#  '2020-03-27 3',
#  '2020-03-27 5',
#  '2020-03-27 10',
#  '2020-03-27 11',
#  '2020-03-27 12',
#  '2020-03-27 13',
#  '2020-03-30 0',
#  '2020-03-30 1',
#  '2020-03-30 2',
#  '2020-03-30 3',
#  '2020-03-30 9',
#  '2020-03-30 12',
#  '2020-03-30 13',
#  '2020-03-30 14',
#  '2020-03-30 0',
#  '2020-03-30 1',
#  '2020-03-30 2',
#  '2020-03-30 3',
#  '2020-03-30 9',
#  '2020-03-30 12',
#  '2020-03-30 13',
#  '2020-03-30 14',
#  '2020-04-02 0',
#  '2020-04-02 1',
#  '2020-04-02 2',
#  '2020-04-02 3',
#  '2020-04-02 4',
#  '2020-04-02 5',
#  '2020-04-02 6',
#  '2020-04-02 7',
#  '2020-04-02 8',
#  '2020-04-02 11',
#  '2020-04-02 12',
#  '2020-04-02 13',
#  '2020-04-04 1',
#  '2020-04-04 2',
#  '2020-04-04 3',
#  '2020-04-04 4',
#  '2020-04-04 5',
#  '2020-04-04 6',
#  '2020-04-04 7',
#  '2020-04-04 8',
#  '2020-04-04 9',
#  '2020-04-04 12',
#  '2020-04-04 13',
#  '2020-04-04 14',
#  '2020-04-06 1',
#  '2020-04-06 2',
#  '2020-04-06 3',
#  '2020-04-06 4',
#  '2020-04-06 5',
#  '2020-04-06 6',
#  '2020-04-06 7',
#  '2020-04-06 8',
#  '2020-04-06 9',
#  '2020-04-06 11',
#  '2020-04-06 12',
#  '2020-04-06 13',
#  '2020-04-06 14',
#  '2020-04-08 0',
#  '2020-04-08 1',
#  '2020-04-08 2',
#  '2020-04-08 3',
#  '2020-04-08 4',
#  '2020-04-08 5',
#  '2020-04-08 7',
#  '2020-04-08 8',
#  '2020-04-08 9',
#  '2020-04-08 10',
#  '2020-04-08 11',
#  '2020-04-08 12',
#  '2020-04-08 14',
#  '2020-04-10 0',
#  '2020-04-10 1',
#  '2020-04-10 2',
#  '2020-04-10 3',
#  '2020-04-10 4',
#  '2020-04-10 5',
#  '2020-04-10 6',
#  '2020-04-10 7',
#  '2020-04-10 8',
#  '2020-04-10 9',
#  '2020-04-10 10',
#  '2020-04-10 11',
#  '2020-04-10 12',
#  '2020-04-10 13',
#  '2020-04-10 14',
#  '2020-04-13 0',
#  '2020-04-13 1',
#  '2020-04-13 2',
#  '2020-04-13 3',
#  '2020-04-13 4',
#  '2020-04-13 5',
#  '2020-04-13 6',
#  '2020-04-13 7',
#  '2020-04-13 8',
#  '2020-04-13 9',
#  '2020-04-13 10',
#  '2020-04-13 11',
#  '2020-04-13 13',
#  '2020-04-15 0',
#  '2020-04-15 1',
#  '2020-04-15 2',
#  '2020-04-15 3',
#  '2020-04-15 4',
#  '2020-04-15 5',
#  '2020-04-15 6',
#  '2020-04-15 7',
#  '2020-04-15 8',
#  '2020-04-15 9',
#  '2020-04-15 10',
#  '2020-04-15 11',
#  '2020-04-15 12',
#  '2020-04-15 13',
#  '2020-04-15 14',
#  '2020-04-20 0',
#  '2020-04-20 1',
#  '2020-04-20 2',
#  '2020-04-20 3',
#  '2020-04-20 4',
#  '2020-04-20 5',
#  '2020-04-20 7',
#  '2020-04-20 8',
#  '2020-04-20 9',
#  '2020-04-20 10',
#  '2020-04-20 11',
#  '2020-04-20 12',
#  '2020-04-20 13',
#  '2020-04-20 14',
#  '2020-04-20 0',
#  '2020-04-20 1',
#  '2020-04-20 2',
#  '2020-04-20 3',
#  '2020-04-20 4',
#  '2020-04-20 5',
#  '2020-04-20 7',
#  '2020-04-20 8',
#  '2020-04-20 9',
#  '2020-04-20 10',
#  '2020-04-20 11',
#  '2020-04-20 12',
#  '2020-04-20 13',
#  '2020-04-20 14',
#  '2020-04-22 0',
#  '2020-04-22 1',
#  '2020-04-22 2',
#  '2020-04-22 3',
#  '2020-04-22 4',
#  '2020-04-22 5',
#  '2020-04-22 6',
#  '2020-04-22 7',
#  '2020-04-22 8',
#  '2020-04-22 9',
#  '2020-04-22 10',
#  '2020-04-22 11',
#  '2020-04-22 12',
#  '2020-04-22 13',
#  '2020-04-22 14',
#  '2020-04-24 0',
#  '2020-04-24 3',
#  '2020-04-24 4',
#  '2020-04-24 5',
#  '2020-04-24 6',
#  '2020-04-24 7',
#  '2020-04-24 8',
#  '2020-04-24 9',
#  '2020-04-24 11',
#  '2020-04-24 13',
#  '2020-04-24 14',
#  '2020-04-28 0',
#  '2020-04-28 2',
#  '2020-04-28 4',
#  '2020-04-28 5',
#  '2020-04-28 6',
#  '2020-04-28 9',
#  '2020-04-28 10',
#  '2020-04-28 11',
#  '2020-04-30 2',
#  '2020-04-30 3',
#  '2020-04-30 4',
#  '2020-04-30 5',
#  '2020-04-30 7',
#  '2020-04-30 8',
#  '2020-04-30 9',
#  '2020-04-30 11',
#  '2020-04-30 12',
#  '2020-04-30 13',
#  '2020-05-01 1',
#  '2020-05-01 2',
#  '2020-05-01 5',
#  '2020-05-01 6',
#  '2020-05-01 10',
#  '2020-05-01 14',
#  '2020-05-04 0',
#  '2020-05-04 1',
#  '2020-05-04 2',
#  '2020-05-04 3',
#  '2020-05-04 4',
#  '2020-05-04 5',
#  '2020-05-04 6',
#  '2020-05-04 7',
#  '2020-05-04 8',
#  '2020-05-04 9',
#  '2020-05-04 11',
#  '2020-05-04 12',
#  '2020-05-04 13',
#  '2020-05-04 14',
#  '2020-05-06 0',
#  '2020-05-06 3',
#  '2020-05-06 6',
#  '2020-05-06 7',
#  '2020-05-06 8',
#  '2020-05-06 12',
#  '2020-05-10 0',
#  '2020-05-10 1',
#  '2020-05-10 2',
#  '2020-05-10 3',
#  '2020-05-10 8',
#  '2020-05-10 9',
#  '2020-05-10 10',
#  '2020-05-10 11',
#  '2020-05-10 12',
#  '2020-05-10 13',
#  '2020-05-10 14',
#  '2020-05-12 6',
#  '2020-05-12 10',
#  '2020-05-12 12',
#  '2020-05-12 13',
#  '2020-05-15 2',
#  '2020-05-15 4',
#  '2020-05-15 5',
#  '2020-05-15 6',
#  '2020-05-15 7',
#  '2020-05-15 8',
#  '2020-05-15 9',
#  '2020-05-15 10',
#  '2020-05-15 12',
#  '2020-05-15 13',
#  '2020-05-15 14',
#  '2020-05-22 0',
#  '2020-05-22 1',
#  '2020-05-22 2',
#  '2020-05-22 3',
#  '2020-05-22 4',
#  '2020-05-22 5',
#  '2020-05-22 6',
#  '2020-05-22 7',
#  '2020-05-22 8',
#  '2020-05-22 9',
#  '2020-05-22 10',
#  '2020-05-22 11',
#  '2020-05-22 12',
#  '2020-05-22 13',
#  '2020-05-26 0',
#  '2020-05-26 1',
#  '2020-05-26 2',
#  '2020-05-26 3',
#  '2020-05-26 4',
#  '2020-05-26 5',
#  '2020-05-26 6',
#  '2020-05-26 7',
#  '2020-05-26 8',
#  '2020-05-26 10',
#  '2020-05-26 11',
#  '2020-05-26 12',
#  '2020-05-26 13',
#  '2020-05-29 1',
#  '2020-05-29 2',
#  '2020-05-29 3',
#  '2020-05-29 4',
#  '2020-05-29 5',
#  '2020-05-29 6',
#  '2020-05-29 7',
#  '2020-05-29 9',
#  '2020-05-29 11',
#  '2020-05-29 12',
#  '2020-05-29 13',
#  '2020-05-29 14',
#  '2020-06-02 0',
#  '2020-06-02 1',
#  '2020-06-02 2',
#  '2020-06-02 3',
#  '2020-06-02 4',
#  '2020-06-02 5',
#  '2020-06-02 6',
#  '2020-06-02 7',
#  '2020-06-02 8',
#  '2020-06-02 9',
#  '2020-06-02 10',
#  '2020-06-02 11',
#  '2020-06-02 12',
#  '2020-06-02 13',
#  '2020-06-02 14',
#  '2020-06-05 0',
#  '2020-06-05 1',
#  '2020-06-05 2',
#  '2020-06-05 3',
#  '2020-06-05 5',
#  '2020-06-05 6',
#  '2020-06-05 7',
#  '2020-06-05 8',
#  '2020-06-05 9',
#  '2020-06-05 10',
#  '2020-06-05 11',
#  '2020-06-05 12',
#  '2020-06-05 13',
#  '2020-06-05 14',
#  '2020-06-07 0',
#  '2020-06-07 1',
#  '2020-06-07 2',
#  '2020-06-07 3',
#  '2020-06-07 4',
#  '2020-06-07 5',
#  '2020-06-07 6',
#  '2020-06-07 8',
#  '2020-06-07 9',
#  '2020-06-07 10',
#  '2020-06-07 12',
#  '2020-06-07 13',
#  '2020-06-07 14',
#  '2020-06-10 1',
#  '2020-06-10 2',
#  '2020-06-10 3',
#  '2020-06-10 4',
#  '2020-06-10 5',
#  '2020-06-10 6',
#  '2020-06-10 9',
#  '2020-06-10 10',
#  '2020-06-10 11',
#  '2020-06-10 12',
#  '2020-06-10 13',
#  '2020-06-10 14',
#  '2020-06-17 1',
#  '2020-06-17 4',
#  '2020-06-17 5',
#  '2020-06-17 6',
#  '2020-06-17 7',
#  '2020-06-17 8',
#  '2020-06-17 9',
#  '2020-06-17 12',
#  '2020-06-17 13',
#  '2020-06-17 14',
#  '2020-06-20 0',
#  '2020-06-20 1',
#  '2020-06-20 2',
#  '2020-06-20 3',
#  '2020-06-20 4',
#  '2020-06-20 5',
#  '2020-06-20 6',
#  '2020-06-20 9',
#  '2020-06-22 2',
#  '2020-06-22 3',
#  '2020-06-22 4',
#  '2020-06-22 6',
#  '2020-06-22 8',
#  '2020-06-22 9',
#  '2020-06-25 1',
#  '2020-06-25 2',
#  '2020-06-25 3',
#  '2020-06-25 5',
#  '2020-06-25 6',
#  '2020-06-25 7',
#  '2020-06-25 8',
#  '2020-06-25 9',
#  '2020-06-25 10',
#  '2020-06-25 11',
#  '2020-06-25 12',
#  '2020-06-25 13',
#  '2020-06-25 14',
#  '2020-06-29 0',
#  '2020-06-29 1',
#  '2020-06-29 5',
#  '2020-06-29 6',
#  '2020-06-29 7',
#  '2020-06-29 9',
#  '2020-06-29 10',
#  '2020-06-29 11',
#  '2020-06-29 12',
#  '2020-06-29 13',
#  '2020-06-29 14',
#  '2020-07-02 0',
#  '2020-07-02 1',
#  '2020-07-02 2',
#  '2020-07-02 3',
#  '2020-07-02 4',
#  '2020-07-02 5',
#  '2020-07-02 6',
#  '2020-07-02 7',
#  '2020-07-02 8',
#  '2020-07-02 10',
#  '2020-07-02 12',
#  '2020-07-02 13',
#  '2020-07-02 14',
#  '2020-07-03 0',
#  '2020-07-03 1',
#  '2020-07-03 2',
#  '2020-07-03 3',
#  '2020-07-03 4',
#  '2020-07-03 5',
#  '2020-07-03 6',
#  '2020-07-03 7',
#  '2020-07-03 8',
#  '2020-07-03 9',
#  '2020-07-03 11',
#  '2020-07-03 12',
#  '2020-07-03 13',
#  '2020-07-05 0',
#  '2020-07-05 1',
#  '2020-07-05 2',
#  '2020-07-05 3',
#  '2020-07-05 4',
#  '2020-07-05 5',
#  '2020-07-05 6',
#  '2020-07-05 7',
#  '2020-07-05 8',
#  '2020-07-05 9',
#  '2020-07-05 10',
#  '2020-07-05 11',
#  '2020-07-05 13',
#  '2020-07-05 14',
#  '2020-07-08 0',
#  '2020-07-08 1',
#  '2020-07-08 2',
#  '2020-07-08 3',
#  '2020-07-08 4',
#  '2020-07-08 5',
#  '2020-07-08 6',
#  '2020-07-08 7',
#  '2020-07-08 9',
#  '2020-07-08 10',
#  '2020-07-08 11',
#  '2020-07-08 12',
#  '2020-07-11 1',
#  '2020-07-11 2',
#  '2020-07-11 3',
#  '2020-07-11 4',
#  '2020-07-11 5',
#  '2020-07-11 6',
#  '2020-07-11 7',
#  '2020-07-11 8',
#  '2020-07-11 9',
#  '2020-07-11 10',
#  '2020-07-11 11',
#  '2020-07-11 12',
#  '2020-07-11 13',
#  '2020-07-11 14',
#  '2020-07-18 1',
#  '2020-07-22 0',
#  '2020-07-22 2',
#  '2020-07-22 3',
#  '2020-07-22 5',
#  '2020-07-22 7',
#  '2020-07-22 8',
#  '2020-07-22 9',
#  '2020-07-22 10',
#  '2020-07-22 11',
#  '2020-07-25 0',
#  '2020-07-25 1',
#  '2020-07-25 2',
#  '2020-07-25 3',
#  '2020-07-25 4',
#  '2020-07-25 5',
#  '2020-07-25 6',
#  '2020-07-25 8',
#  '2020-07-25 9',
#  '2020-07-25 10',
#  '2020-07-25 11',
#  '2020-07-25 12',
#  '2020-07-25 13',
#  '2020-07-25 14',
#  '2020-07-29 0',
#  '2020-07-29 2',
#  '2020-07-29 3',
#  '2020-07-29 4',
#  '2020-08-02 0',
#  '2020-08-02 4',
#  '2020-08-02 8',
#  '2020-08-02 9',
#  '2020-08-12 2',
#  '2020-08-12 8',
#  '2020-08-12 9',
#  '2020-08-12 10',
#  '2020-08-12 11',
#  '2020-08-12 12',
#  '2020-08-15 0',
#  '2020-08-15 1',
#  '2020-08-15 5',
#  '2020-08-15 6',
#  '2020-08-15 7',
#  '2020-08-15 8',
#  '2020-08-15 11',
#  '2020-08-15 12',
#  '2020-08-15 13',
#  '2020-08-17 2',
#  '2020-08-17 3',
#  '2020-08-17 4',
#  '2020-08-17 7',
#  '2020-08-17 8',
#  '2020-08-17 9',
#  '2020-08-17 11',
#  '2020-08-17 12',
#  '2020-08-17 13',
#  '2020-08-19 0',
#  '2020-08-19 2',
#  '2020-08-19 3',
#  '2020-08-19 5',
#  '2020-08-19 6',
#  '2020-08-19 9',
#  '2020-08-19 10',
#  '2020-08-21 0',
#  '2020-08-21 1',
#  '2020-08-21 3',
#  '2020-08-21 5',
#  '2020-08-24 0',
#  '2020-08-24 1',
#  '2020-08-24 2',
#  '2020-08-24 3',
#  '2020-08-24 4',
#  '2020-08-24 5',
#  '2020-08-24 8',
#  '2020-08-26 0',
#  '2020-08-26 1',
#  '2020-08-26 2',
#  '2020-08-26 3',
#  '2020-08-26 4',
#  '2020-08-26 7',
#  '2020-08-28 0',
#  '2020-09-01 0',
#  '2020-09-03 0',
#  '2020-09-03 1',
#  '2020-09-05 0',
#  '2020-09-05 1',
#  '2020-09-07 0',
#  '2020-09-07 2',
#  '2020-09-07 3',
#  '2020-09-11 0',
#  '2020-09-11 1',
#  '2020-09-11 2',
#  '2020-09-11 3',
#  '2020-09-11 7',
#  '2020-09-11 8',
#  '2020-09-13 0',
#  '2020-09-13 1',
#  '2020-09-13 2',
#  '2020-09-13 4',
#  '2020-09-13 5',
#  '2020-09-13 6',
#  '2020-09-13 7',
#  '2020-09-16 1',
#  '2020-09-16 3',
#  '2020-09-16 4',
#  '2020-09-16 6',
#  '2020-09-16 7',
#  '2020-09-16 9',
#  '2020-09-16 10',
#  '2020-09-18 0',
#  '2020-09-18 1',
#  '2020-09-18 3',
#  '2020-09-18 5',
#  '2020-09-18 6',
#  '2020-09-18 8',
#  '2020-09-18 9',
#  '2020-09-18 10',
#  '2020-09-20 0',
#  '2020-09-20 1',
#  '2020-09-20 2',
#  '2020-09-20 3',
#  '2020-09-20 4',
#  '2020-09-20 5',
#  '2020-09-20 7',
#  '2020-09-20 8',
#  '2020-09-20 9',
#  '2020-09-23 0',
#  '2020-09-23 1',
#  '2020-09-23 5',
#  '2020-09-23 6',
#  '2020-09-23 7',
#  '2020-09-23 10',
#  '2020-09-23 12',
#  '2020-09-24 0',
#  '2020-09-24 3',
#  '2020-09-24 4',
#  '2020-09-24 5',
#  '2020-09-24 6',
#  '2020-09-24 7',
#  '2020-09-24 11',
#  '2020-09-25 0',
#  '2020-09-25 2',
#  '2020-09-25 5',
#  '2020-09-25 10',
#  '2020-09-25 11',
#  '2020-09-27 1',
#  '2020-09-27 2',
#  '2020-09-27 3',
#  '2020-09-27 6',
#  '2020-09-27 8',
#  '2020-09-27 12',
#  '2020-10-01 0',
#  '2020-10-01 4',
#  '2020-10-01 5',
#  '2020-10-01 6',
#  '2020-10-01 7',
#  '2020-10-01 8',
#  '2020-10-01 10',
#  '2020-10-01 11',
#  '2020-10-01 12',
#  '2020-10-01 13',
#  '2020-10-01 14',
#  '2020-10-03 0',
#  '2020-10-03 1',
#  '2020-10-03 2',
#  '2020-10-03 3',
#  '2020-10-03 4',
#  '2020-10-03 5',
#  '2020-10-03 6',
#  '2020-10-03 9',
#  '2020-10-03 11',
#  '2020-10-03 12',
#  '2020-10-03 13',
#  '2020-10-05 0',
#  '2020-10-05 1',
#  '2020-10-05 3',
#  '2020-10-05 4',
#  '2020-10-05 5',
#  '2020-10-05 7',
#  '2020-10-05 10',
#  '2020-10-05 12',
#  '2020-10-05 13',
#  '2020-10-08 4',
#  '2020-10-08 5',
#  '2020-10-08 7',
#  '2020-10-08 8',
#  '2020-10-08 9',
#  '2020-10-08 11',
#  '2020-10-08 12',
#  '2020-10-08 13',
#  '2020-10-10 2',
#  '2020-10-10 3',
#  '2020-10-10 4',
#  '2020-10-10 7',
#  '2020-10-10 9',
#  '2020-10-10 12',
#  '2020-10-10 13',
#  '2020-10-10 14',
#  '2020-10-10 2',
#  '2020-10-10 3',
#  '2020-10-10 4',
#  '2020-10-10 7',
#  '2020-10-10 9',
#  '2020-10-10 12',
#  '2020-10-10 13',
#  '2020-10-10 14',
#  '2020-10-13 1',
#  '2020-10-13 2',
#  '2020-10-13 4',
#  '2020-10-13 5',
#  '2020-10-13 8',
#  '2020-10-13 9',
#  '2020-10-13 11',
#  '2020-10-13 12',
#  '2020-10-13 14',
#  '2020-10-15 0',
#  '2020-10-15 1',
#  '2020-10-15 2',
#  '2020-10-15 3',
#  '2020-10-15 4',
#  '2020-10-15 5',
#  '2020-10-15 6',
#  '2020-10-15 7',
#  '2020-10-15 8',
#  '2020-10-15 9',
#  '2020-10-15 11',
#  '2020-10-15 12',
#  '2020-10-15 13',
#  '2020-10-15 14',
#  '2020-10-17 0',
#  '2020-10-17 1',
#  '2020-10-17 2',
#  '2020-10-17 3',
#  '2020-10-17 4',
#  '2020-10-17 5',
#  '2020-10-17 6',
#  '2020-10-17 7',
#  '2020-10-17 8',
#  '2020-10-17 9',
#  '2020-10-17 10',
#  '2020-10-17 12',
#  '2020-10-17 13',
#  '2020-10-17 14',
#  '2020-10-19 0',
#  '2020-10-19 1',
#  '2020-10-19 2',
#  '2020-10-19 3',
#  '2020-10-19 4',
#  '2020-10-19 5',
#  '2020-10-19 7',
#  '2020-10-19 8',
#  '2020-10-19 9',
#  '2020-10-19 11',
#  '2020-10-19 12',
#  '2020-10-19 13',
#  '2020-10-19 14',
#  '2020-10-21 0',
#  '2020-10-21 1',
#  '2020-10-21 2',
#  '2020-10-21 3',
#  '2020-10-21 4',
#  '2020-10-21 5',
#  '2020-10-21 7',
#  '2020-10-21 8',
#  '2020-10-21 9',
#  '2020-10-21 10',
#  '2020-10-21 11',
#  '2020-10-21 12',
#  '2020-10-23 0',
#  '2020-10-23 1',
#  '2020-10-23 2',
#  '2020-10-23 3',
#  '2020-10-23 5',
#  '2020-10-23 7',
#  '2020-10-23 8',
#  '2020-10-23 9',
#  '2020-10-23 11',
#  '2020-10-23 12',
#  '2020-10-23 13',
#  '2020-10-25 1',
#  '2020-10-25 2',
#  '2020-10-25 4',
#  '2020-10-25 5',
#  '2020-10-25 6',
#  '2020-10-25 7',
#  '2020-10-25 8',
#  '2020-10-25 9',
#  '2020-10-25 10',
#  '2020-10-25 11',
#  '2020-10-25 14',
#  '2020-10-28 1',
#  '2020-10-28 2',
#  '2020-10-28 5',
#  '2020-10-28 6',
#  '2020-10-28 8',
#  '2020-10-28 9',
#  '2020-10-28 10',
#  '2020-10-28 11',
#  '2020-10-28 12',
#  '2020-10-28 14',
#  '2020-10-31 0',
#  '2020-10-31 2',
#  '2020-10-31 5',
#  '2020-10-31 6',
#  '2020-10-31 7',
#  '2020-10-31 8',
#  '2020-10-31 9',
#  '2020-10-31 11',
#  '2020-10-31 12',
#  '2020-10-31 14',
#  '2020-11-02 0',
#  '2020-11-02 2',
#  '2020-11-02 4',
#  '2020-11-02 5',
#  '2020-11-02 7',
#  '2020-11-02 8',
#  '2020-11-02 9',
#  '2020-11-02 10',
#  '2020-11-02 11',
#  '2020-11-02 12',
#  '2020-11-02 13',
#  '2020-11-02 14',
#  '2020-11-04 0',
#  '2020-11-04 1',
#  '2020-11-04 2',
#  '2020-11-04 4',
#  '2020-11-04 5',
#  '2020-11-04 6',
#  '2020-11-04 7',
#  '2020-11-04 8',
#  '2020-11-04 9',
#  '2020-11-04 11',
#  '2020-11-04 12',
#  '2020-11-05 0',
#  '2020-11-05 2',
#  '2020-11-05 3',
#  '2020-11-05 4',
#  '2020-11-05 5',
#  '2020-11-05 6',
#  '2020-11-05 7',
#  '2020-11-05 8',
#  '2020-11-05 10',
#  '2020-11-05 12',
#  '2020-11-05 13',
#  '2020-11-05 14',
#  '2020-11-10 1',
#  '2020-11-10 3',
#  '2020-11-10 4',
#  '2020-11-10 5',
#  '2020-11-10 6',
#  '2020-11-10 7',
#  '2020-11-10 10',
#  '2020-11-10 11',
#  '2020-11-10 12',
#  ...]

# %%
L1f_swp = 'ICON_L1_FUV_SWP_2020-02-17_v05r000.NC'
parts = L1f_swp.split('_')
day = str(parts[4])

swp_p0 = data_opening_w_stripe('P0',L1f_swp)
swp = orbits_finder(swp_p0)[8]
wavelength_plots(swp,day,8,17)
# Out:
# [811.3609332800002,
#  885.1210181236365,
#  973.6331199360002,
#  1145.4507293364707,
#  1298.1774932480002,
#  1497.8971075938464]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
L1f_swp = 'ICON_L1_FUV_SWP_2020-07-25_v05r000.NC'
parts = L1f_swp.split('_')
day = str(parts[4])

swp_p0 = data_opening_w_stripe('P0',L1f_swp)
swp = orbits_finder(swp_p0)[12]
wavelength_plots(swp,day,12,17)
# Out:
# [294.82454545454544,
#  318.9904918032787,
#  367.14000000000004,
#  442.2368181818182,
#  474.5956097560976,
#  627.6909677419357,
#  884.4736363636364,
#  1144.6129411764707,
#  1496.8015384615387]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
L1f_swp = 'ICON_L1_FUV_SWP_2020-09-16_v05r000.NC'
parts = L1f_swp.split('_')
day = str(parts[4])

swp_p0 = data_opening_w_stripe('P0',L1f_swp)
swp = orbits_finder(swp_p0)[4]
wavelength_plots(swp,day,4,17)
# Out:
# [525.2530434782609, 575.2771428571428, 1006.735]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### DOMINANT PEAK FINDER- 17 SAMPLE

# %%
# Define the directory path (change this to your directory)
directory_path = "/Users/pkoll/ICON_FUV"

# Use glob to find all CSV files in the directory
file_pattern = os.path.join(directory_path, '*.nc')  
files = glob.glob(file_pattern)

all_dists = []

# Check if we found more than 1 file
if len(files) > 1:
    print(f"Found {len(files)} files. Processing...")

    # Iterate over the files and process each one
    for file_path in files:
        try:
           # print(file_path)
            file_name = os.path.basename(file_path)
           # print(file_name)
            
            swp_p0 = data_opening_w_stripe('P0',file_name)             
            
            # Day Name
            parts = file_name.split('_')
            day = parts[4]

            print("All Data Opened for", day)

            for orbit in range(0,15):
                swp_data = orbits_finder(swp_p0)[orbit]
                result = dominant_wavelength_finder(swp_data,day,orbit,17)
                dist_vals = result[0]

                all_dists.append(dist_vals)
            
            print(f' DONE: Entirely Processed {day}')
        
        except Exception as e:
            print(f"Error processing {file_path}: {e}")

else:
    print(f"Found only {len(files)} files. Not enough files to process.")
# Out:
# Found 132 files. Processing...
# Error processing /Users/pkoll/ICON_FUV\ICON_L0P_FUV_Ancillary_2020-09-24_v03r002.NC: cannot access local variable 'dsf' where it is not associated with a value
# All Data Opened for 2019-11-16
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_LWP_2019-11-16_v05r001.NC: 'Dataset' object has no attribute 'I_1356'
# All Data Opened for 2020-01-01
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_LWP_2020-01-01_v05r000.NC: 'Dataset' object has no attribute 'I_1356'
# All Data Opened for 2020-01-02
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_LWP_2020-01-02_v05r001.NC: 'Dataset' object has no attribute 'I_1356'
# All Data Opened for 2020-03-22
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_LWP_2020-03-22_v05r000.NC: 'Dataset' object has no attribute 'I_1356'
# All Data Opened for 2020-05-10
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_LWP_2020-05-10_v05r000.NC: 'Dataset' object has no attribute 'I_1356'
# All Data Opened for 2020-01-01
#  DONE: Entirely Processed 2020-01-01
# All Data Opened for 2020-01-02
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-01-02_v05r001.NC: list index out of range
# All Data Opened for 2020-01-07
#  DONE: Entirely Processed 2020-01-07
# All Data Opened for 2020-01-11
#  DONE: Entirely Processed 2020-01-11
# All Data Opened for 2020-01-15
#  DONE: Entirely Processed 2020-01-15
# All Data Opened for 2020-01-19
#  DONE: Entirely Processed 2020-01-19
# All Data Opened for 2020-01-23
#  DONE: Entirely Processed 2020-01-23
# All Data Opened for 2020-02-06
#  DONE: Entirely Processed 2020-02-06
# All Data Opened for 2020-02-08
#  DONE: Entirely Processed 2020-02-08
# All Data Opened for 2020-02-10
#  DONE: Entirely Processed 2020-02-10
# All Data Opened for 2020-02-12
#  DONE: Entirely Processed 2020-02-12
# All Data Opened for 2020-02-15
#  DONE: Entirely Processed 2020-02-15
# All Data Opened for 2020-02-17
#  DONE: Entirely Processed 2020-02-17
# All Data Opened for 2020-02-25
#  DONE: Entirely Processed 2020-02-25
# All Data Opened for 2020-02-28
#  DONE: Entirely Processed 2020-02-28
# All Data Opened for 2020-03-06
#  DONE: Entirely Processed 2020-03-06
# All Data Opened for 2020-03-11
#  DONE: Entirely Processed 2020-03-11
# All Data Opened for 2020-03-11
#  DONE: Entirely Processed 2020-03-11
# All Data Opened for 2020-03-15
#  DONE: Entirely Processed 2020-03-15
# All Data Opened for 2020-03-20
#  DONE: Entirely Processed 2020-03-20
# All Data Opened for 2020-03-22
#  DONE: Entirely Processed 2020-03-22
# All Data Opened for 2020-03-25
#  DONE: Entirely Processed 2020-03-25
# All Data Opened for 2020-03-27
#  DONE: Entirely Processed 2020-03-27
# All Data Opened for 2020-03-30
#  DONE: Entirely Processed 2020-03-30
# All Data Opened for 2020-03-30
#  DONE: Entirely Processed 2020-03-30
# All Data Opened for 2020-04-02
#  DONE: Entirely Processed 2020-04-02
# All Data Opened for 2020-04-04
#  DONE: Entirely Processed 2020-04-04
# All Data Opened for 2020-04-06
#  DONE: Entirely Processed 2020-04-06
# All Data Opened for 2020-04-08
#  DONE: Entirely Processed 2020-04-08
# All Data Opened for 2020-04-10
#  DONE: Entirely Processed 2020-04-10
# All Data Opened for 2020-04-13
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-04-13_v05r000.NC: list index out of range
# All Data Opened for 2020-04-15
#  DONE: Entirely Processed 2020-04-15
# All Data Opened for 2020-04-20
#  DONE: Entirely Processed 2020-04-20
# All Data Opened for 2020-04-20
#  DONE: Entirely Processed 2020-04-20
# All Data Opened for 2020-04-22
#  DONE: Entirely Processed 2020-04-22
# All Data Opened for 2020-04-24
#  DONE: Entirely Processed 2020-04-24
# All Data Opened for 2020-04-28
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-04-28_v05r000.NC: list index out of range
# All Data Opened for 2020-04-30
#  DONE: Entirely Processed 2020-04-30
# All Data Opened for 2020-05-01
#  DONE: Entirely Processed 2020-05-01
# All Data Opened for 2020-05-04
#  DONE: Entirely Processed 2020-05-04
# All Data Opened for 2020-05-06
#  DONE: Entirely Processed 2020-05-06
# All Data Opened for 2020-05-10
#  DONE: Entirely Processed 2020-05-10
# All Data Opened for 2020-05-12
#  DONE: Entirely Processed 2020-05-12
# All Data Opened for 2020-05-15
#  DONE: Entirely Processed 2020-05-15
# All Data Opened for 2020-05-22
#  DONE: Entirely Processed 2020-05-22
# All Data Opened for 2020-05-26
#  DONE: Entirely Processed 2020-05-26
# All Data Opened for 2020-05-29
#  DONE: Entirely Processed 2020-05-29
# All Data Opened for 2020-06-02
#  DONE: Entirely Processed 2020-06-02
# All Data Opened for 2020-06-05
#  DONE: Entirely Processed 2020-06-05
# All Data Opened for 2020-06-07
#  DONE: Entirely Processed 2020-06-07
# All Data Opened for 2020-06-10
#  DONE: Entirely Processed 2020-06-10
# All Data Opened for 2020-06-17
#  DONE: Entirely Processed 2020-06-17
# All Data Opened for 2020-06-20
#  DONE: Entirely Processed 2020-06-20
# All Data Opened for 2020-06-22
#  DONE: Entirely Processed 2020-06-22
# All Data Opened for 2020-06-25
#  DONE: Entirely Processed 2020-06-25
# All Data Opened for 2020-06-29
#  DONE: Entirely Processed 2020-06-29
# All Data Opened for 2020-07-02
#  DONE: Entirely Processed 2020-07-02
# All Data Opened for 2020-07-03
#  DONE: Entirely Processed 2020-07-03
# All Data Opened for 2020-07-05
#  DONE: Entirely Processed 2020-07-05
# All Data Opened for 2020-07-08
#  DONE: Entirely Processed 2020-07-08
# All Data Opened for 2020-07-11
#  DONE: Entirely Processed 2020-07-11
# All Data Opened for 2020-07-15
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-07-15_v05r000.NC: list index out of range
# All Data Opened for 2020-07-18
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-07-18_v05r000.NC: list index out of range
# All Data Opened for 2020-07-22
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-07-22_v05r000.NC: list index out of range
# All Data Opened for 2020-07-25
#  DONE: Entirely Processed 2020-07-25
# All Data Opened for 2020-07-29
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-07-29_v05r000.NC: list index out of range
# All Data Opened for 2020-08-02
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-08-02_v05r001.NC: list index out of range
# All Data Opened for 2020-08-12
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-08-12_v05r000.NC: list index out of range
# All Data Opened for 2020-08-15
#  DONE: Entirely Processed 2020-08-15
# All Data Opened for 2020-08-17
#  DONE: Entirely Processed 2020-08-17
# All Data Opened for 2020-08-19
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-08-19_v05r000.NC: list index out of range
# All Data Opened for 2020-08-21
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-08-21_v05r000.NC: list index out of range
# All Data Opened for 2020-08-24
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-08-24_v05r000.NC: list index out of range
# All Data Opened for 2020-08-26
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-08-26_v05r000.NC: list index out of range
# All Data Opened for 2020-08-28
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-08-28_v05r000.NC: list index out of range
# All Data Opened for 2020-09-01
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-01_v05r000.NC: list index out of range
# All Data Opened for 2020-09-03
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-03_v05r000.NC: list index out of range
# All Data Opened for 2020-09-05
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-05_v05r000.NC: list index out of range
# All Data Opened for 2020-09-07
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-07_v05r000.NC: list index out of range
# All Data Opened for 2020-09-11
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-11_v05r000.NC: list index out of range
# All Data Opened for 2020-09-13
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-13_v05r000.NC: list index out of range
# All Data Opened for 2020-09-16
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-16_v05r000.NC: list index out of range
# All Data Opened for 2020-09-18
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-18_v05r000.NC: list index out of range
# All Data Opened for 2020-09-20
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-20_v05r000.NC: list index out of range
# All Data Opened for 2020-09-23
#  DONE: Entirely Processed 2020-09-23
# All Data Opened for 2020-09-24
#  DONE: Entirely Processed 2020-09-24
# All Data Opened for 2020-09-25
#  DONE: Entirely Processed 2020-09-25
# All Data Opened for 2020-09-27
#  DONE: Entirely Processed 2020-09-27
# All Data Opened for 2020-10-01
#  DONE: Entirely Processed 2020-10-01
# All Data Opened for 2020-10-03
#  DONE: Entirely Processed 2020-10-03
# All Data Opened for 2020-10-05
#  DONE: Entirely Processed 2020-10-05
# All Data Opened for 2020-10-08
#  DONE: Entirely Processed 2020-10-08
# All Data Opened for 2020-10-10
#  DONE: Entirely Processed 2020-10-10
# All Data Opened for 2020-10-10
#  DONE: Entirely Processed 2020-10-10
# All Data Opened for 2020-10-13
#  DONE: Entirely Processed 2020-10-13
# All Data Opened for 2020-10-15
#  DONE: Entirely Processed 2020-10-15
# All Data Opened for 2020-10-17
#  DONE: Entirely Processed 2020-10-17
# All Data Opened for 2020-10-19
#  DONE: Entirely Processed 2020-10-19
# All Data Opened for 2020-10-21
#  DONE: Entirely Processed 2020-10-21
# All Data Opened for 2020-10-23
#  DONE: Entirely Processed 2020-10-23
# All Data Opened for 2020-10-25
#  DONE: Entirely Processed 2020-10-25
# All Data Opened for 2020-10-28
#  DONE: Entirely Processed 2020-10-28
# All Data Opened for 2020-10-31
#  DONE: Entirely Processed 2020-10-31
# All Data Opened for 2020-11-02
#  DONE: Entirely Processed 2020-11-02
# All Data Opened for 2020-11-04
#  DONE: Entirely Processed 2020-11-04
# All Data Opened for 2020-11-05
#  DONE: Entirely Processed 2020-11-05
# All Data Opened for 2020-11-10
#  DONE: Entirely Processed 2020-11-10
# All Data Opened for 2020-11-13
#  DONE: Entirely Processed 2020-11-13
# All Data Opened for 2020-11-17
#  DONE: Entirely Processed 2020-11-17
# All Data Opened for 2020-11-22
#  DONE: Entirely Processed 2020-11-22
# All Data Opened for 2020-11-25
#  DONE: Entirely Processed 2020-11-25
# All Data Opened for 2020-11-28
#  DONE: Entirely Processed 2020-11-28
# All Data Opened for 2020-11-30
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-11-30_v05r000 (1).NC: list index out of range
# All Data Opened for 2020-11-30
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-11-30_v05r000.NC: list index out of range
# All Data Opened for 2020-12-02
#  DONE: Entirely Processed 2020-12-02
# All Data Opened for 2020-12-05
#  DONE: Entirely Processed 2020-12-05
# All Data Opened for 2020-12-09
#  DONE: Entirely Processed 2020-12-09
# All Data Opened for 2020-12-13
#  DONE: Entirely Processed 2020-12-13
# All Data Opened for 2020-12-16
#  DONE: Entirely Processed 2020-12-16
# All Data Opened for 2020-12-18
#  DONE: Entirely Processed 2020-12-18
# All Data Opened for 2020-12-20
#  DONE: Entirely Processed 2020-12-20
# All Data Opened for 2020-12-22
#  DONE: Entirely Processed 2020-12-22
# All Data Opened for 2020-12-25
#  DONE: Entirely Processed 2020-12-25
# All Data Opened for 2020-12-27
#  DONE: Entirely Processed 2020-12-27
# All Data Opened for 2020-12-30
#  DONE: Entirely Processed 2020-12-30
# All Data Opened for 2020-12-31
#  DONE: Entirely Processed 2020-12-31

# %%
plt.figure()
# Create histogram
plt.hist(all_dists, bins = 50, edgecolor='black')

# Add titles and labels
plt.title('Distribution of Distances')
plt.xlabel('Distance Values (km)')
plt.ylabel('Frequency')
# Show
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### DOMINANT PEAK FINDER - 23 SAMPLE

# %%
# Define the directory path (change this to your directory)
directory_path = "/Users/pkoll/ICON_FUV"

# Use glob to find all CSV files in the directory
file_pattern = os.path.join(directory_path, '*.nc')  
files = glob.glob(file_pattern)

all_dists = []

# Check if we found more than 1 file
if len(files) > 1:
    print(f"Found {len(files)} files. Processing...")

    # Iterate over the files and process each one
    for file_path in files:
        try:
           # print(file_path)
            file_name = os.path.basename(file_path)
           # print(file_name)
            
            swp_p0 = data_opening_w_stripe('P0',file_name)             
            
            # Day Name
            parts = file_name.split('_')
            day = parts[4]

            print("All Data Opened for", day)

            for orbit in range(0,15):
                swp_data = orbits_finder(swp_p0)[orbit]
                result = dominant_wavelength_finder(swp_data,day,orbit,23)
                dist_vals = result[0]

                all_dists.append(dist_vals)
            
            print(f' DONE: Entirely Processed {day}')
        
        except Exception as e:
            print(f"Error processing {file_path}: {e}")

else:
    print(f"Found only {len(files)} files. Not enough files to process.")
# Out:
# Found 132 files. Processing...
# Error processing /Users/pkoll/ICON_FUV\ICON_L0P_FUV_Ancillary_2020-09-24_v03r002.NC: cannot access local variable 'dsf' where it is not associated with a value
# All Data Opened for 2019-11-16
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_LWP_2019-11-16_v05r001.NC: 'Dataset' object has no attribute 'I_1356'
# All Data Opened for 2020-01-01
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_LWP_2020-01-01_v05r000.NC: 'Dataset' object has no attribute 'I_1356'
# All Data Opened for 2020-01-02
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_LWP_2020-01-02_v05r001.NC: 'Dataset' object has no attribute 'I_1356'
# All Data Opened for 2020-03-22
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_LWP_2020-03-22_v05r000.NC: 'Dataset' object has no attribute 'I_1356'
# All Data Opened for 2020-05-10
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_LWP_2020-05-10_v05r000.NC: 'Dataset' object has no attribute 'I_1356'
# All Data Opened for 2020-01-01
#  DONE: Entirely Processed 2020-01-01
# All Data Opened for 2020-01-02
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-01-02_v05r001.NC: list index out of range
# All Data Opened for 2020-01-07
#  DONE: Entirely Processed 2020-01-07
# All Data Opened for 2020-01-11
#  DONE: Entirely Processed 2020-01-11
# All Data Opened for 2020-01-15
#  DONE: Entirely Processed 2020-01-15
# All Data Opened for 2020-01-19
#  DONE: Entirely Processed 2020-01-19
# All Data Opened for 2020-01-23
#  DONE: Entirely Processed 2020-01-23
# All Data Opened for 2020-02-06
#  DONE: Entirely Processed 2020-02-06
# All Data Opened for 2020-02-08
#  DONE: Entirely Processed 2020-02-08
# All Data Opened for 2020-02-10
#  DONE: Entirely Processed 2020-02-10
# All Data Opened for 2020-02-12
#  DONE: Entirely Processed 2020-02-12
# All Data Opened for 2020-02-15
#  DONE: Entirely Processed 2020-02-15
# All Data Opened for 2020-02-17
#  DONE: Entirely Processed 2020-02-17
# All Data Opened for 2020-02-25
#  DONE: Entirely Processed 2020-02-25
# All Data Opened for 2020-02-28
#  DONE: Entirely Processed 2020-02-28
# All Data Opened for 2020-03-06
#  DONE: Entirely Processed 2020-03-06
# All Data Opened for 2020-03-11
#  DONE: Entirely Processed 2020-03-11
# All Data Opened for 2020-03-11
#  DONE: Entirely Processed 2020-03-11
# All Data Opened for 2020-03-15
#  DONE: Entirely Processed 2020-03-15
# All Data Opened for 2020-03-20
#  DONE: Entirely Processed 2020-03-20
# All Data Opened for 2020-03-22
#  DONE: Entirely Processed 2020-03-22
# All Data Opened for 2020-03-25
#  DONE: Entirely Processed 2020-03-25
# All Data Opened for 2020-03-27
#  DONE: Entirely Processed 2020-03-27
# All Data Opened for 2020-03-30
#  DONE: Entirely Processed 2020-03-30
# All Data Opened for 2020-03-30
#  DONE: Entirely Processed 2020-03-30
# All Data Opened for 2020-04-02
#  DONE: Entirely Processed 2020-04-02
# All Data Opened for 2020-04-04
#  DONE: Entirely Processed 2020-04-04
# All Data Opened for 2020-04-06
#  DONE: Entirely Processed 2020-04-06
# All Data Opened for 2020-04-08
#  DONE: Entirely Processed 2020-04-08
# All Data Opened for 2020-04-10
#  DONE: Entirely Processed 2020-04-10
# All Data Opened for 2020-04-13
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-04-13_v05r000.NC: list index out of range
# All Data Opened for 2020-04-15
#  DONE: Entirely Processed 2020-04-15
# All Data Opened for 2020-04-20
#  DONE: Entirely Processed 2020-04-20
# All Data Opened for 2020-04-20
#  DONE: Entirely Processed 2020-04-20
# All Data Opened for 2020-04-22
#  DONE: Entirely Processed 2020-04-22
# All Data Opened for 2020-04-24
#  DONE: Entirely Processed 2020-04-24
# All Data Opened for 2020-04-28
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-04-28_v05r000.NC: list index out of range
# All Data Opened for 2020-04-30
#  DONE: Entirely Processed 2020-04-30
# All Data Opened for 2020-05-01
#  DONE: Entirely Processed 2020-05-01
# All Data Opened for 2020-05-04
#  DONE: Entirely Processed 2020-05-04
# All Data Opened for 2020-05-06
#  DONE: Entirely Processed 2020-05-06
# All Data Opened for 2020-05-10
#  DONE: Entirely Processed 2020-05-10
# All Data Opened for 2020-05-12
#  DONE: Entirely Processed 2020-05-12
# All Data Opened for 2020-05-15
#  DONE: Entirely Processed 2020-05-15
# All Data Opened for 2020-05-22
#  DONE: Entirely Processed 2020-05-22
# All Data Opened for 2020-05-26
#  DONE: Entirely Processed 2020-05-26
# All Data Opened for 2020-05-29
#  DONE: Entirely Processed 2020-05-29
# All Data Opened for 2020-06-02
#  DONE: Entirely Processed 2020-06-02
# All Data Opened for 2020-06-05
#  DONE: Entirely Processed 2020-06-05
# All Data Opened for 2020-06-07
#  DONE: Entirely Processed 2020-06-07
# All Data Opened for 2020-06-10
#  DONE: Entirely Processed 2020-06-10
# All Data Opened for 2020-06-17
#  DONE: Entirely Processed 2020-06-17
# All Data Opened for 2020-06-20
#  DONE: Entirely Processed 2020-06-20
# All Data Opened for 2020-06-22
#  DONE: Entirely Processed 2020-06-22
# All Data Opened for 2020-06-25
#  DONE: Entirely Processed 2020-06-25
# All Data Opened for 2020-06-29
#  DONE: Entirely Processed 2020-06-29
# All Data Opened for 2020-07-02
#  DONE: Entirely Processed 2020-07-02
# All Data Opened for 2020-07-03
#  DONE: Entirely Processed 2020-07-03
# All Data Opened for 2020-07-05
#  DONE: Entirely Processed 2020-07-05
# All Data Opened for 2020-07-08
#  DONE: Entirely Processed 2020-07-08
# All Data Opened for 2020-07-11
#  DONE: Entirely Processed 2020-07-11
# All Data Opened for 2020-07-15
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-07-15_v05r000.NC: list index out of range
# All Data Opened for 2020-07-18
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-07-18_v05r000.NC: list index out of range
# All Data Opened for 2020-07-22
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-07-22_v05r000.NC: list index out of range
# All Data Opened for 2020-07-25
#  DONE: Entirely Processed 2020-07-25
# All Data Opened for 2020-07-29
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-07-29_v05r000.NC: list index out of range
# All Data Opened for 2020-08-02
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-08-02_v05r001.NC: list index out of range
# All Data Opened for 2020-08-12
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-08-12_v05r000.NC: list index out of range
# All Data Opened for 2020-08-15
#  DONE: Entirely Processed 2020-08-15
# All Data Opened for 2020-08-17
#  DONE: Entirely Processed 2020-08-17
# All Data Opened for 2020-08-19
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-08-19_v05r000.NC: list index out of range
# All Data Opened for 2020-08-21
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-08-21_v05r000.NC: list index out of range
# All Data Opened for 2020-08-24
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-08-24_v05r000.NC: list index out of range
# All Data Opened for 2020-08-26
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-08-26_v05r000.NC: list index out of range
# All Data Opened for 2020-08-28
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-08-28_v05r000.NC: list index out of range
# All Data Opened for 2020-09-01
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-01_v05r000.NC: list index out of range
# All Data Opened for 2020-09-03
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-03_v05r000.NC: list index out of range
# All Data Opened for 2020-09-05
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-05_v05r000.NC: list index out of range
# All Data Opened for 2020-09-07
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-07_v05r000.NC: list index out of range
# All Data Opened for 2020-09-11
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-11_v05r000.NC: list index out of range
# All Data Opened for 2020-09-13
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-13_v05r000.NC: list index out of range
# All Data Opened for 2020-09-16
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-16_v05r000.NC: list index out of range
# All Data Opened for 2020-09-18
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-18_v05r000.NC: list index out of range
# All Data Opened for 2020-09-20
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-09-20_v05r000.NC: list index out of range
# All Data Opened for 2020-09-23
#  DONE: Entirely Processed 2020-09-23
# All Data Opened for 2020-09-24
#  DONE: Entirely Processed 2020-09-24
# All Data Opened for 2020-09-25
#  DONE: Entirely Processed 2020-09-25
# All Data Opened for 2020-09-27
#  DONE: Entirely Processed 2020-09-27
# All Data Opened for 2020-10-01
#  DONE: Entirely Processed 2020-10-01
# All Data Opened for 2020-10-03
#  DONE: Entirely Processed 2020-10-03
# All Data Opened for 2020-10-05
#  DONE: Entirely Processed 2020-10-05
# All Data Opened for 2020-10-08
#  DONE: Entirely Processed 2020-10-08
# All Data Opened for 2020-10-10
#  DONE: Entirely Processed 2020-10-10
# All Data Opened for 2020-10-10
#  DONE: Entirely Processed 2020-10-10
# All Data Opened for 2020-10-13
#  DONE: Entirely Processed 2020-10-13
# All Data Opened for 2020-10-15
#  DONE: Entirely Processed 2020-10-15
# All Data Opened for 2020-10-17
#  DONE: Entirely Processed 2020-10-17
# All Data Opened for 2020-10-19
#  DONE: Entirely Processed 2020-10-19
# All Data Opened for 2020-10-21
#  DONE: Entirely Processed 2020-10-21
# All Data Opened for 2020-10-23
#  DONE: Entirely Processed 2020-10-23
# All Data Opened for 2020-10-25
#  DONE: Entirely Processed 2020-10-25
# All Data Opened for 2020-10-28
#  DONE: Entirely Processed 2020-10-28
# All Data Opened for 2020-10-31
#  DONE: Entirely Processed 2020-10-31
# All Data Opened for 2020-11-02
#  DONE: Entirely Processed 2020-11-02
# All Data Opened for 2020-11-04
#  DONE: Entirely Processed 2020-11-04
# All Data Opened for 2020-11-05
#  DONE: Entirely Processed 2020-11-05
# All Data Opened for 2020-11-10
#  DONE: Entirely Processed 2020-11-10
# All Data Opened for 2020-11-13
#  DONE: Entirely Processed 2020-11-13
# All Data Opened for 2020-11-17
#  DONE: Entirely Processed 2020-11-17
# All Data Opened for 2020-11-22
#  DONE: Entirely Processed 2020-11-22
# All Data Opened for 2020-11-25
#  DONE: Entirely Processed 2020-11-25
# All Data Opened for 2020-11-28
#  DONE: Entirely Processed 2020-11-28
# All Data Opened for 2020-11-30
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-11-30_v05r000 (1).NC: list index out of range
# All Data Opened for 2020-11-30
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_SWP_2020-11-30_v05r000.NC: list index out of range
# All Data Opened for 2020-12-02
#  DONE: Entirely Processed 2020-12-02
# All Data Opened for 2020-12-05
#  DONE: Entirely Processed 2020-12-05
# All Data Opened for 2020-12-09
#  DONE: Entirely Processed 2020-12-09
# All Data Opened for 2020-12-13
#  DONE: Entirely Processed 2020-12-13
# All Data Opened for 2020-12-16
#  DONE: Entirely Processed 2020-12-16
# All Data Opened for 2020-12-18
#  DONE: Entirely Processed 2020-12-18
# All Data Opened for 2020-12-20
#  DONE: Entirely Processed 2020-12-20
# All Data Opened for 2020-12-22
#  DONE: Entirely Processed 2020-12-22
# All Data Opened for 2020-12-25
#  DONE: Entirely Processed 2020-12-25
# All Data Opened for 2020-12-27
#  DONE: Entirely Processed 2020-12-27
# All Data Opened for 2020-12-30
#  DONE: Entirely Processed 2020-12-30
# All Data Opened for 2020-12-31
#  DONE: Entirely Processed 2020-12-31

# %%
plt.figure()
# Create histogram
plt.hist(all_dists, bins = 50, edgecolor='black')

# Add titles and labels
plt.title('Distribution of Distances')
plt.xlabel('Distance Values (km)')
plt.ylabel('Frequency')
# Show
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
