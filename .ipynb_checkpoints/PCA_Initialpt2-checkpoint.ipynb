# %%
# %matplotlib ipympl
# % matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import datetime
import glob
import netCDF4
import xarray as xr
import pandas as pd
import seaborn as sns
#plt.style.use('seaborn')
import os
from scipy import stats

# %% [markdown]
# #### Data Opening Functions

# %%
def data_opening_w_stripe(stripe, d):
    dsf_raw = xr.open_dataset(d,engine = 'netcdf4')  

    # FOR FUV A SWP
    if 'ICON_L1_FUVA_SWP_Center_Times' in dsf_raw.variables.keys():
        dsf = dsf_raw[['ICON_L1_FUVA_SWP_Center_Times','ICON_L1_FUVA_SWP_PROF_'+str(stripe)]]
        # Convert times to something Python and xarray can understand, and reindex the dataset by time 
        t = pd.to_datetime(dsf.ICON_L1_FUVA_SWP_Center_Times.values)
        dsf['time'] = (['Epoch'], t)
        dsf = dsf.swap_dims({'Epoch':'time'})
        dsf = dsf.rename({'Rows':'row'})
        # Rename and drop useless variables
        dsf['I_1356'] = dsf['ICON_L1_FUVA_SWP_PROF_'+str(stripe)]
        dsf = dsf.drop(['ICON_L1_FUVA_SWP_PROF_'+str(stripe),'ICON_L1_FUVA_SWP_Center_Times','Epoch'])
    
    # FOR FUV B LWP
    elif 'ICON_L1_FUVB_LWP_Center_Times' in dsf_raw.variables.keys():
        dsf = dsf_raw[['ICON_L1_FUVB_LWP_Center_Times','ICON_L1_FUVB_LWP_PROF_'+str(stripe)]]
        # Convert times to something Python and xarray can understand, and reindex the dataset by time 
        t = pd.to_datetime(dsf.ICON_L1_FUVB_LWP_Center_Times.values)
        dsf['time'] = (['Epoch'], t)
        dsf = dsf.swap_dims({'Epoch':'time'})
        dsf = dsf.rename({'Rows':'row'})
        #  Rename and drop useless variables
        dsf['N2'] = dsf['ICON_L1_FUVB_LWP_PROF_'+str(stripe)]
        dsf = dsf.drop(['ICON_L1_FUVB_LWP_PROF_'+str(stripe),'ICON_L1_FUVB_LWP_Center_Times','Epoch'])    
      
    return dsf

# %% [markdown]
# #### Orbit Separation Functions

# %%
def orbits_finder(df):
    from scipy.signal import find_peaks
    data = df.I_1356.mean(dim = 'row')
    data_np = data.to_numpy()
    np.shape(data)

    max_data = max(data_np)
    time_diff = pd.to_timedelta('75 m')
    half_time_diff = pd.to_timedelta('50 m')

    indices = find_peaks(data, height = max_data * (4/6)) 

    indexes = indices[0]
    indexes 

    final_indexes = []

    for i in range(0,len(indexes)-1):
        if len(indexes) > 15:
            if indexes[i+1] - indexes[i] < 200:
                pass
            else:
                final_indexes.append(indexes[i])
        else:
            final_indexes.append(indexes[i])
    final_indexes.append(indexes[-1])
    
    times_np = df.time.to_numpy()
    times_dt = pd.to_datetime(times_np)
    
    all_orbits = []
    for i in final_indexes:
        start_time = times_dt[i] - half_time_diff
        end_time = start_time + time_diff
        df_orbit = df.sel(time=slice(start_time, end_time))
        all_orbits.append(df_orbit)
        
    return all_orbits

# %%
def single_orb(orbit_arr,n):   
    orb = orbit_arr[n].mean(dim = 'row')
    t = orb.time

    
    if 'I_1356' in orb.variables.keys():
        val = orb.I_1356
    elif 'N2' in orb.variables.keys():
        val = orb.N2
        
    return(t, val)

# %%
def single_orb_with_row(orbit_arr,n):   
    orb = orbit_arr[n]
    t = orb.time
    val = orb.I_1356
    r = orb.row

    return(t, val, r)

# %%
L1f_swp_01 = 'ICON_L1_FUV_SWP_2020-01-01_v05r000.NC'

# %% [markdown]
# #### IDEA: PCA

# %%
# incorporate rows

# %%
def orbits_finder_filt(df):
    from scipy.signal import find_peaks
    
    data = df.I_1356.mean(dim = 'row')
    
    time_diff = pd.to_timedelta('75 m')
    half_time_diff = pd.to_timedelta('50 m')
    # Instead of time_diff for slices, use a specific number of points on both sides of the peak (180)
    
    # Rolling Mean average over data 
    data_smoothed = data.rolling(time = 100, center = False).mean()

    indices = find_peaks(data_smoothed) 

    indexes = indices[0]
    indexes 

    final_indexes = []

    times_np = df.time.to_numpy()
    times_dt = pd.to_datetime(times_np)
    
    all_orbits = []
    for i in indexes:
        start_time = times_dt[i] - half_time_diff
        end_time = start_time + time_diff
        df_orbit = df.sel(time=slice(start_time, end_time))


        # ORBIT FILTERING

        arr = df_orbit.I_1356.mean(dim = 'row')
        
        zero_counter = 0

        # Y_val < 100
        for val in arr:
            if val <= 50:
                zero_counter += 1


        if zero_counter/len(arr) < 0.35 and len(arr) > 300: # check this lim         
            all_orbits.append(df_orbit)


    return all_orbits

# %%
L1f_swp_01 = 'ICON_L1_FUV_SWP_2020-11-04_v05r000.NC'
swp_p0 = data_opening_w_stripe('P0',L1f_swp_01)
swp_p0_all = orbits_finder_filt(swp_p0)

# %%
len(swp_p0_all) # ONLY 9 orbits vs 15!
# Out:
# 9

# %%
swp_p0_all[0]
# Out:
# <xarray.Dataset>
# Dimensions:  (row: 256, time: 365)
# Coordinates:
#   * row      (row) float32 0.0 1.0 2.0 3.0 4.0 ... 251.0 252.0 253.0 254.0 255.0
#   * time     (time) datetime64[ns] 2020-11-04T00:30:31.917000 ... 2020-11-04T...
# Data variables:
#     I_1356   (time, row) float32 -3.531 -3.387 -3.231 ... -0.4659 -1.928 -0.9389
# Attributes: (12/51)
#     Acknowledgement:             This is a data product from the NASA Ionosph...
#     ADID_Ref:                    NASA Contract > NNG12F45C
#     Calibration_File:            See calibration files in general attribute f...
#     Conventions:                 SPDF ISTP/IACF Modified for NetCDF (v0.8)
#     Data_Level:                  L1
#     Data_Type:                   APIDxE3 > ICON Application ID 0xE3: FUV Scie...
#     ...                          ...
#     FLATFIELD_CORRECTION:        [1.159 1.057 1.011 0.952 0.919 0.91 ]
#     BACKGROUND_CORRECTION:       sw_bkg_2020-309.txt
#     RAYLEIGH_CONVERSION:         [0.04407962 0.04407962 0.04407962 ... 0.0440...
#     File_Date:                   Wed, 27 Apr 2022, 2022-04-27T00:11:45.043 UTC
#     Generation_Date:             20220427
#     Software_Version:            ICON SDC > ICON FUV L1 Processor version 202...

# %%
sel_orb = single_orb_with_row(swp_p0_all,0)
sel_orb[1]
# Out:
# <xarray.DataArray 'I_1356' (time: 365, row: 256)>
# array([[-3.53096 , -3.387049, -3.230543, ..., -1.634661, -3.01451 , -2.429188],
#        [-4.68384 , -4.106206, -3.529303, ..., -2.983355, -1.957085, -3.2147  ],
#        [-3.919871, -1.944888, -2.663648, ..., -1.389528, -1.970873, -1.252577],
#        ...,
#        [-4.783338, -5.673386, -4.292476, ..., -2.686915, -2.007862, -1.958543],
#        [-6.634694, -6.916815, -5.715214, ..., -0.903372, -2.552616, -2.075608],
#        [-6.908596, -8.268625, -6.57298 , ..., -0.465872, -1.927786, -0.938902]],
#       dtype=float32)
# Coordinates:
#   * row      (row) float32 0.0 1.0 2.0 3.0 4.0 ... 251.0 252.0 253.0 254.0 255.0
#   * time     (time) datetime64[ns] 2020-11-04T00:30:31.917000 ... 2020-11-04T...
# Attributes: (12/19)
#     TYPE:          float (4-bytes)
#     CATDESC:       FUVA SW channel altitude column brightness for 0 to +3 deg...
#     CONTENT:       FUVA SW channel altitude column brightness for 0 to +3 deg...
#     DEPEND_0:      Epoch
#     DEPEND_1:      Rows
#     DISPLAY_TYPE:  spectrogram
#     ...            ...
#     VAR_TYPE:      data
#     SCALETYP:      linear
#     VAR_NOTES:     Vertical profile for 0 to +3 degrees FOV
#     Valid_Min:     -1000000.0
#     Valid_Max:     1000000.0
#     Time_Base:     FIXED: 1970-01-01 UTC

# %%
L1f_swp_01 = 'ICON_L1_FUV_SWP_2020-05-10_v05r000.NC'
swp_p0 = data_opening_w_stripe('P0',L1f_swp_01)
swp_p0_all = orbits_finder_filt(swp_p0)

plt.figure()
for i in range(0,len(swp_p0_all)):
    sel_orb = single_orb_with_row(swp_p0_all,i)
    plt.plot(sel_orb[1].mean(dim = 'row'),marker = '.',label = "Orbit " + str(i))
    print(len(sel_orb[1]))
plt.legend()
plt.show()
# Out:
# 364
# 365
# 365
# 365
# 365
# 365
# 365
# 365
# 365
# 365
# 303
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
L1f_swp_01 = 'ICON_L1_FUV_SWP_2020-01-01_v05r000.NC'
swp_p0 = data_opening_w_stripe('P0',L1f_swp_01)
swp_p0_all = orbits_finder_filt(swp_p0)

plt.figure()
for i in range(0,len(swp_p0_all)):
    sel_orb = single_orb_with_row(swp_p0_all,i)
    plt.plot(sel_orb[1].mean(dim = 'row'),marker = '.',label = "Orbit " + str(i))
    print(len(sel_orb[1]))
plt.legend()
plt.show()
# Out:
# 325
# 365
# 365
# 365
# 365
# 335
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
L1f_swp_01 = 'ICON_L1_FUV_SWP_2020-11-30_v05r000.NC'
swp_p0 = data_opening_w_stripe('P0',L1f_swp_01)
swp_p0_all = orbits_finder_filt(swp_p0)

swp_norm = orbits_finder(swp_p0)
plt.figure()
for i in range(0,len(swp_p0_all)):
    sel_orb = single_orb_with_row(swp_p0_all,i)
    plt.plot(sel_orb[1].mean(dim = 'row'),marker = '.',label = "Orbit " + str(i))
    print(len(sel_orb[1]))
plt.legend()
plt.show()
# Out:
# 364
# 365
# 365
# 365
# 365
# 365
# 365
# 312
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Everything!

# %%
# Define the directory path (change this to your directory)
directory_path = "/Users/pkoll/ICON_FUV"

# Use glob to find all files in the directory
file_pattern = os.path.join(directory_path, '*.nc')  
files = glob.glob(file_pattern)

orbits = []
counter = 0
counter2 = 0
counter3 = 0

# fig = plt.figure()
# ax = fig.add_subplot(1, 1, 1) 

# Check if we found more than 1 file
if len(files) > 1:
    print(f"Found {len(files)} files. Processing...")

    # Iterate over the files and process each one
    for file_path in files:
        try:
           # print(file_path)
            file_name = os.path.basename(file_path)
           # print(file_name)
            
            swp_p0 = data_opening_w_stripe('P0',file_name)             
            
            # Day Name
            parts = file_name.split('_')
            day = parts[4]

            print("All Data Opened for", day)
            
            swp_p0_all = orbits_finder_filt(swp_p0)
            
            for i in range(0,len(swp_p0_all)):
                sel_orb = single_orb_with_row(swp_p0_all,i)

                if len(sel_orb[1]) == 365:
                    counter += 1
                    print(counter,len(sel_orb[1]))
                    
                    orbits.append(sel_orb[1])
                
                elif len(sel_orb[1]) == 364:
                    counter2 += 1
                    print('364',counter2,len(sel_orb[1]))

                else:
                    counter3 += 1
                    print('OTHER',counter3,len(sel_orb[1]))

            print(f' DONE: Entirely Processed {day}')
        
        except Exception as e:
            print(f"Error processing {file_path}: {e}")

else:
    print(f"Found only {len(files)} files. Not enough files to process.")
# Out:
# Found 131 files. Processing...
# Error processing /Users/pkoll/ICON_FUV\ICON_L0P_FUV_Ancillary_2020-09-24_v03r002.NC: cannot access local variable 'dsf' where it is not associated with a value
# All Data Opened for 2019-11-16
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_LWP_2019-11-16_v05r001.NC: 'Dataset' object has no attribute 'I_1356'
# All Data Opened for 2020-01-01
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_LWP_2020-01-01_v05r000.NC: 'Dataset' object has no attribute 'I_1356'
# All Data Opened for 2020-01-02
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_LWP_2020-01-02_v05r001.NC: 'Dataset' object has no attribute 'I_1356'
# All Data Opened for 2020-03-22
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_LWP_2020-03-22_v05r000.NC: 'Dataset' object has no attribute 'I_1356'
# All Data Opened for 2020-05-10
# Error processing /Users/pkoll/ICON_FUV\ICON_L1_FUV_LWP_2020-05-10_v05r000.NC: 'Dataset' object has no attribute 'I_1356'
# All Data Opened for 2020-01-01
# OTHER 1 325
# 1 365
# 2 365
# 3 365
# 4 365
# OTHER 2 335
#  DONE: Entirely Processed 2020-01-01
# All Data Opened for 2020-01-02
# OTHER 3 341
# 5 365
# 6 365
# 7 365
# 8 365
#  DONE: Entirely Processed 2020-01-02
# All Data Opened for 2020-01-07
# 9 365
# 10 365
# 11 365
# 12 365
# OTHER 4 319
# OTHER 5 351
#  DONE: Entirely Processed 2020-01-07
# All Data Opened for 2020-01-11
# 13 365
# 14 365
# 15 365
# OTHER 6 321
# OTHER 7 321
# 16 365
#  DONE: Entirely Processed 2020-01-11
# All Data Opened for 2020-01-15
# 17 365
# OTHER 8 360
# 18 365
# 19 365
#  DONE: Entirely Processed 2020-01-15
# All Data Opened for 2020-01-19
# OTHER 9 341
# 20 365
# 21 365
# 22 365
#  DONE: Entirely Processed 2020-01-19
# All Data Opened for 2020-01-23
# OTHER 10 322
#  DONE: Entirely Processed 2020-01-23
# All Data Opened for 2020-02-06
# 364 1 364
# 23 365
# 24 365
# 25 365
# 26 365
# 27 365
# 28 365
# 29 365
# 30 365
# 31 365
#  DONE: Entirely Processed 2020-02-06
# All Data Opened for 2020-02-08
# 32 365
# 33 365
# 34 365
# 35 365
# 36 365
# 37 365
# 38 365
# 39 365
# 40 365
#  DONE: Entirely Processed 2020-02-08
# All Data Opened for 2020-02-10
# 364 2 364
# 41 365
# 42 365
# 43 365
# 44 365
# 45 365
# 46 365
# 47 365
#  DONE: Entirely Processed 2020-02-10
# All Data Opened for 2020-02-12
# 48 365
# 49 365
# 50 365
# 51 365
# 52 365
# 53 365
# 54 365
#  DONE: Entirely Processed 2020-02-12
# All Data Opened for 2020-02-15
# OTHER 11 357
# 55 365
# 56 365
# 57 365
# 58 365
# 59 365
# 60 365
# 61 365
#  DONE: Entirely Processed 2020-02-15
# All Data Opened for 2020-02-17
# 364 3 364
# 62 365
# 63 365
# 64 365
# 65 365
# 66 365
# 67 365
#  DONE: Entirely Processed 2020-02-17
# All Data Opened for 2020-02-25
# 68 365
# 69 365
# 70 365
# 71 365
# 72 365
#  DONE: Entirely Processed 2020-02-25
# All Data Opened for 2020-02-28
# OTHER 12 343
# 73 365
# 74 365
# 75 365
# 364 4 364
# 76 365
# 77 365
#  DONE: Entirely Processed 2020-02-28
# All Data Opened for 2020-03-06
# 78 365
# 79 365
# 80 365
# 81 365
# 82 365
# 83 365
# 84 365
#  DONE: Entirely Processed 2020-03-06
# All Data Opened for 2020-03-11
# 85 365
# 86 365
# 87 365
# 88 365
# 89 365
# 90 365
# 91 365
# 92 365
#  DONE: Entirely Processed 2020-03-11
# All Data Opened for 2020-03-11
# 93 365
# 94 365
# 95 365
# 96 365
# 97 365
# 98 365
# 99 365
# 100 365
#  DONE: Entirely Processed 2020-03-11
# All Data Opened for 2020-03-15
# 101 365
# 102 365
# 103 365
# 104 365
# 105 365
# 106 365
# 107 365
# 108 365
# 109 365
# 110 365
# 364 5 364
#  DONE: Entirely Processed 2020-03-15
# All Data Opened for 2020-03-20
# 111 365
# 112 365
# 113 365
# 114 365
# 115 365
# 364 6 364
# 116 365
# 117 365
# 118 365
# 119 365
# 120 365
#  DONE: Entirely Processed 2020-03-20
# All Data Opened for 2020-03-22
# 364 7 364
# 121 365
# 122 365
# 123 365
# 124 365
# 125 365
# 126 365
# 127 365
# 128 365
# 129 365
# 130 365
#  DONE: Entirely Processed 2020-03-22
# All Data Opened for 2020-03-25
# OTHER 13 308
# OTHER 14 322
# 131 365
# 132 365
# 133 365
# 134 365
# 135 365
# 136 365
# 137 365
# 138 365
# 139 365
# 140 365
#  DONE: Entirely Processed 2020-03-25
# All Data Opened for 2020-03-27
# 364 8 364
# 141 365
# 142 365
# 143 365
# 144 365
# 145 365
# 146 365
# 147 365
# 148 365
# 149 365
# 364 9 364
#  DONE: Entirely Processed 2020-03-27
# All Data Opened for 2020-03-30
# 364 10 364
# 150 365
# 151 365
# 152 365
# 153 365
# 154 365
# 155 365
# 156 365
# 157 365
# OTHER 15 323
#  DONE: Entirely Processed 2020-03-30
# All Data Opened for 2020-03-30
# 364 11 364
# 158 365
# 159 365
# 160 365
# 161 365
# 162 365
# 163 365
# 164 365
# 165 365
# OTHER 16 323
#  DONE: Entirely Processed 2020-03-30
# All Data Opened for 2020-04-02
# 166 365
# 167 365
# 168 365
# 169 365
# 170 365
# 171 365
# 172 365
# 173 365
#  DONE: Entirely Processed 2020-04-02
# All Data Opened for 2020-04-04
# 174 365
# 175 365
# 176 365
# 177 365
# 178 365
# 179 365
# 180 365
#  DONE: Entirely Processed 2020-04-04
# All Data Opened for 2020-04-06
# 181 365
# 182 365
# 183 365
# 184 365
# 185 365
# 186 365
# 187 365
# 364 12 364
#  DONE: Entirely Processed 2020-04-06
# All Data Opened for 2020-04-08
# OTHER 17 315
# 188 365
# OTHER 18 304
#  DONE: Entirely Processed 2020-04-08
# All Data Opened for 2020-04-10
#  DONE: Entirely Processed 2020-04-10
# All Data Opened for 2020-04-13
#  DONE: Entirely Processed 2020-04-13
# All Data Opened for 2020-04-15
#  DONE: Entirely Processed 2020-04-15
# All Data Opened for 2020-04-20
# 189 365
# 190 365
# 191 365
# 192 365
# 193 365
# 194 365
# 195 365
# 196 365
#  DONE: Entirely Processed 2020-04-20
# All Data Opened for 2020-04-20
# 197 365
# 198 365
# 199 365
# 200 365
# 201 365
# 202 365
# 203 365
# 204 365
#  DONE: Entirely Processed 2020-04-20
# All Data Opened for 2020-04-22
# OTHER 19 344
# 205 365
# OTHER 20 367
# 206 365
# 364 13 364
# 364 14 364
# 364 15 364
# 207 365
# 208 365
# 209 365
# 210 365
#  DONE: Entirely Processed 2020-04-22
# All Data Opened for 2020-04-24
# 211 365
# 212 365
# 213 365
# 214 365
# 215 365
# 216 365
# 217 365
# 218 365
# 219 365
# 220 365
#  DONE: Entirely Processed 2020-04-24
# All Data Opened for 2020-04-28
# 221 365
# 222 365
# 223 365
# 224 365
# 225 365
# 226 365
# 227 365
# 228 365
# 229 365
#  DONE: Entirely Processed 2020-04-28
# All Data Opened for 2020-04-30
# 230 365
# 231 365
# 232 365
# 233 365
# 234 365
# 235 365
# 236 365
# 237 365
# 238 365
# 239 365
# 240 365
#  DONE: Entirely Processed 2020-04-30
# All Data Opened for 2020-05-01
# 241 365
# 242 365
# 243 365
# 244 365
# 245 365
# 246 365
# 247 365
# 248 365
# 249 365
# 250 365
# 251 365
# 252 365
#  DONE: Entirely Processed 2020-05-01
# All Data Opened for 2020-05-04
# 253 365
# 254 365
# 255 365
# 256 365
# 257 365
# 258 365
# 259 365
# 260 365
# 261 365
# 262 365
# 263 365
# 264 365
# 364 16 364
#  DONE: Entirely Processed 2020-05-04
# All Data Opened for 2020-05-06
# OTHER 21 346
# 265 365
# 266 365
# 267 365
# 268 365
# 269 365
# 270 365
# 271 365
# 272 365
# 273 365
# 274 365
# 275 365
# 364 17 364
# 364 18 364
#  DONE: Entirely Processed 2020-05-06
# All Data Opened for 2020-05-10
# 364 19 364
# 276 365
# 277 365
# 278 365
# 279 365
# 280 365
# 281 365
# 282 365
# 283 365
# 284 365
# OTHER 22 303
#  DONE: Entirely Processed 2020-05-10
# All Data Opened for 2020-05-12
# OTHER 23 315
# OTHER 24 346
# OTHER 25 347
# OTHER 26 346
# OTHER 27 346
# OTHER 28 344
# OTHER 29 344
# OTHER 30 344
# OTHER 31 343
#  DONE: Entirely Processed 2020-05-12
# All Data Opened for 2020-05-15
# 285 365
# 286 365
# 287 365
# 288 365
# 289 365
# 290 365
# 291 365
# 292 365
# 293 365
# 294 365
#  DONE: Entirely Processed 2020-05-15
# All Data Opened for 2020-05-22
#  DONE: Entirely Processed 2020-05-22
# All Data Opened for 2020-05-26
#  DONE: Entirely Processed 2020-05-26
# All Data Opened for 2020-05-29
#  DONE: Entirely Processed 2020-05-29
# All Data Opened for 2020-06-02
#  DONE: Entirely Processed 2020-06-02
# All Data Opened for 2020-06-05
#  DONE: Entirely Processed 2020-06-05
# All Data Opened for 2020-06-07
# 295 365
# 296 365
# 297 365
# 298 365
# 299 365
#  DONE: Entirely Processed 2020-06-07
# All Data Opened for 2020-06-10
# 300 365
# 301 365
# 302 365
# 303 365
# 304 365
# 305 365
# 306 365
# 307 365
# 308 365
#  DONE: Entirely Processed 2020-06-10
# All Data Opened for 2020-06-17
# 309 365
# 310 365
# 311 365
# 312 365
# 313 365
# 314 365
# 315 365
# 316 365
# 317 365
# 318 365
# 319 365
# 364 20 364
#  DONE: Entirely Processed 2020-06-17
# All Data Opened for 2020-06-20
# 364 21 364
# 320 365
# 321 365
# 322 365
# 323 365
# 324 365
# 325 365
# 326 365
# 327 365
# 328 365
# 329 365
# 330 365
#  DONE: Entirely Processed 2020-06-20
# All Data Opened for 2020-06-22
# 364 22 364
# 331 365
# 332 365
# 333 365
# 334 365
# 335 365
# 336 365
# 337 365
# 338 365
# 339 365
# 340 365
# 341 365
# 364 23 364
# 342 365
#  DONE: Entirely Processed 2020-06-22
# All Data Opened for 2020-06-25
# 364 24 364
# 343 365
# 344 365
# 345 365
# 346 365
# 347 365
# 348 365
# 349 365
# 350 365
# 351 365
# 352 365
#  DONE: Entirely Processed 2020-06-25
# All Data Opened for 2020-06-29
# OTHER 32 340
# 353 365
# 354 365
# 355 365
# 356 365
# 357 365
# 358 365
# 359 365
# 360 365
# 361 365
# 362 365
# 364 25 364
#  DONE: Entirely Processed 2020-06-29
# All Data Opened for 2020-07-02
# 363 365
# 364 365
# 365 365
# 366 365
# 367 365
# 368 365
# 369 365
# 370 365
# 371 365
# 372 365
# 373 365
# OTHER 33 357
#  DONE: Entirely Processed 2020-07-02
# All Data Opened for 2020-07-03
# 364 26 364
# 374 365
# 375 365
# 376 365
# 377 365
# 378 365
# 379 365
# 380 365
# 381 365
# OTHER 34 323
#  DONE: Entirely Processed 2020-07-03
# All Data Opened for 2020-07-05
# 364 27 364
# 382 365
# 383 365
# 384 365
# 385 365
# OTHER 35 309
# 386 365
# 387 365
# 364 28 364
# 388 365
#  DONE: Entirely Processed 2020-07-05
# All Data Opened for 2020-07-08
# OTHER 36 363
# OTHER 37 363
# OTHER 38 363
# OTHER 39 363
# OTHER 40 363
# OTHER 41 363
# OTHER 42 363
# 364 29 364
#  DONE: Entirely Processed 2020-07-08
# All Data Opened for 2020-07-11
# OTHER 43 363
# OTHER 44 363
# OTHER 45 363
# OTHER 46 363
# OTHER 47 363
# OTHER 48 363
# 364 30 364
#  DONE: Entirely Processed 2020-07-11
# All Data Opened for 2020-07-15
#  DONE: Entirely Processed 2020-07-15
# All Data Opened for 2020-07-18
#  DONE: Entirely Processed 2020-07-18
# All Data Opened for 2020-07-22
#  DONE: Entirely Processed 2020-07-22
# All Data Opened for 2020-07-25
# OTHER 49 308
# OTHER 50 310
# OTHER 51 311
# OTHER 52 329
# 389 365
# 390 365
# 391 365
# 392 365
#  DONE: Entirely Processed 2020-07-25
# All Data Opened for 2020-07-29
# OTHER 53 314
# OTHER 54 315
# OTHER 55 313
# OTHER 56 305
#  DONE: Entirely Processed 2020-07-29
# All Data Opened for 2020-08-02
# OTHER 57 322
# OTHER 58 319
# OTHER 59 311
# OTHER 60 306
# OTHER 61 314
# OTHER 62 316
# OTHER 63 320
# OTHER 64 320
#  DONE: Entirely Processed 2020-08-02
# All Data Opened for 2020-08-12
# OTHER 65 302
# OTHER 66 306
# OTHER 67 307
# OTHER 68 302
# OTHER 69 323
#  DONE: Entirely Processed 2020-08-12
# All Data Opened for 2020-08-15
# OTHER 70 313
# OTHER 71 320
# OTHER 72 309
# OTHER 73 307
# OTHER 74 312
# OTHER 75 313
# OTHER 76 306
# OTHER 77 304
# OTHER 78 301
# OTHER 79 321
#  DONE: Entirely Processed 2020-08-15
# All Data Opened for 2020-08-17
# OTHER 80 318
# OTHER 81 310
# OTHER 82 318
# OTHER 83 321
# OTHER 84 315
# OTHER 85 321
# OTHER 86 322
#  DONE: Entirely Processed 2020-08-17
# All Data Opened for 2020-08-19
# OTHER 87 305
# OTHER 88 307
# OTHER 89 310
# OTHER 90 321
#  DONE: Entirely Processed 2020-08-19
# All Data Opened for 2020-08-21
# OTHER 91 315
# OTHER 92 306
# OTHER 93 314
# OTHER 94 322
#  DONE: Entirely Processed 2020-08-21
# All Data Opened for 2020-08-24
# OTHER 95 320
# OTHER 96 301
# OTHER 97 302
# OTHER 98 344
# OTHER 99 321
# OTHER 100 323
# OTHER 101 303
# OTHER 102 301
# OTHER 103 301
# OTHER 104 327
# OTHER 105 317
#  DONE: Entirely Processed 2020-08-24
# All Data Opened for 2020-08-26
# OTHER 106 311
# OTHER 107 318
# OTHER 108 350
# OTHER 109 302
# OTHER 110 315
# OTHER 111 311
#  DONE: Entirely Processed 2020-08-26
# All Data Opened for 2020-08-28
# OTHER 112 301
#  DONE: Entirely Processed 2020-08-28
# All Data Opened for 2020-09-01
#  DONE: Entirely Processed 2020-09-01
# All Data Opened for 2020-09-03
#  DONE: Entirely Processed 2020-09-03
# All Data Opened for 2020-09-05
#  DONE: Entirely Processed 2020-09-05
# All Data Opened for 2020-09-07
# OTHER 113 301
# OTHER 114 303
#  DONE: Entirely Processed 2020-09-07
# All Data Opened for 2020-09-11
# OTHER 115 312
# OTHER 116 306
# OTHER 117 310
# OTHER 118 309
# OTHER 119 304
#  DONE: Entirely Processed 2020-09-11
# All Data Opened for 2020-09-13
# OTHER 120 309
# OTHER 121 319
# OTHER 122 302
# OTHER 123 302
#  DONE: Entirely Processed 2020-09-13
# All Data Opened for 2020-09-16
# OTHER 124 310
# OTHER 125 320
# OTHER 126 310
#  DONE: Entirely Processed 2020-09-16
# All Data Opened for 2020-09-18
# OTHER 127 318
# OTHER 128 316
# OTHER 129 322
# OTHER 130 316
# OTHER 131 313
# OTHER 132 310
#  DONE: Entirely Processed 2020-09-18
# All Data Opened for 2020-09-20
# OTHER 133 321
# OTHER 134 320
# OTHER 135 312
# OTHER 136 308
# OTHER 137 316
# OTHER 138 318
# OTHER 139 321
# OTHER 140 324
# OTHER 141 323
# OTHER 142 323
# OTHER 143 329
#  DONE: Entirely Processed 2020-09-20
# All Data Opened for 2020-09-23
# 393 365
# 394 365
# 395 365
# 396 365
# 397 365
# 398 365
# 399 365
# 400 365
# 401 365
# 402 365
# 403 365
# 404 365
# 364 31 364
# OTHER 144 324
#  DONE: Entirely Processed 2020-09-23
# All Data Opened for 2020-09-24
# 405 365
# 406 365
# 407 365
# 408 365
# 409 365
# 410 365
# 411 365
# 412 365
# 413 365
# 414 365
# 415 365
# 416 365
# 364 32 364
#  DONE: Entirely Processed 2020-09-24
# All Data Opened for 2020-09-25
# 417 365
# 418 365
# 419 365
# 420 365
# 421 365
# 364 33 364
# 422 365
# 423 365
# 424 365
# 425 365
# 426 365
# OTHER 145 362
# 364 34 364
# 364 35 364
#  DONE: Entirely Processed 2020-09-25
# All Data Opened for 2020-09-27
# 427 365
# 428 365
# 429 365
# 430 365
# 431 365
# 364 36 364
# 432 365
# 433 365
# 434 365
# 435 365
# 436 365
# 437 365
# 364 37 364
#  DONE: Entirely Processed 2020-09-27
# All Data Opened for 2020-10-01
# OTHER 146 305
# 438 365
# 439 365
# 440 365
# 441 365
# 442 365
# 443 365
# 444 365
# 445 365
# 446 365
# 447 365
#  DONE: Entirely Processed 2020-10-01
# All Data Opened for 2020-10-03
# 448 365
# 449 365
# 450 365
# 451 365
# 452 365
# 453 365
# 454 365
# 455 365
# 456 365
# 457 365
#  DONE: Entirely Processed 2020-10-03
# All Data Opened for 2020-10-05
# 364 38 364
# 458 365
# 459 365
# 460 365
# 461 365
# 462 365
# 463 365
# 464 365
# 465 365
# 466 365
# OTHER 147 358
#  DONE: Entirely Processed 2020-10-05
# All Data Opened for 2020-10-08
# 467 365
# 468 365
# 469 365
# 470 365
# 471 365
# 472 365
# 473 365
# 474 365
# 475 365
#  DONE: Entirely Processed 2020-10-08
# All Data Opened for 2020-10-10
# 476 365
# 477 365
# 478 365
# 479 365
# 480 365
# 481 365
# 482 365
#  DONE: Entirely Processed 2020-10-10
# All Data Opened for 2020-10-13
# 483 365
# 484 365
# 485 365
# 486 365
# 487 365
# 488 365
# 489 365
#  DONE: Entirely Processed 2020-10-13
# All Data Opened for 2020-10-15
# OTHER 148 307
# 490 365
# 491 365
# 492 365
# 493 365
# 494 365
# 495 365
# 496 365
#  DONE: Entirely Processed 2020-10-15
# All Data Opened for 2020-10-17
# 497 365
# 498 365
# 499 365
# 500 365
# 501 365
# 502 365
# 364 39 364
# 503 365
#  DONE: Entirely Processed 2020-10-17
# All Data Opened for 2020-10-19
# 504 365
# 505 365
# 506 365
# 507 365
# 508 365
# 509 365
# 364 40 364
# OTHER 149 355
#  DONE: Entirely Processed 2020-10-19
# All Data Opened for 2020-10-21
# 510 365
# 511 365
# 512 365
# 513 365
# 514 365
# 515 365
#  DONE: Entirely Processed 2020-10-21
# All Data Opened for 2020-10-23
# 516 365
# 517 365
# 518 365
# 519 365
# 364 41 364
# 520 365
# 521 365
#  DONE: Entirely Processed 2020-10-23
# All Data Opened for 2020-10-25
# 522 365
# 523 365
# 524 365
# 525 365
# 526 365
# 364 42 364
# 527 365
# 528 365
#  DONE: Entirely Processed 2020-10-25
# All Data Opened for 2020-10-28
# 529 365
# 530 365
# 364 43 364
# 531 365
# 532 365
# 533 365
# 534 365
# 535 365
#  DONE: Entirely Processed 2020-10-28
# All Data Opened for 2020-10-31
# 536 365
# 537 365
# 538 365
# 539 365
# OTHER 150 306
# 540 365
# 541 365
# 542 365
# 543 365
#  DONE: Entirely Processed 2020-10-31
# All Data Opened for 2020-11-02
# 544 365
# 545 365
# 546 365
# 547 365
# 548 365
# 549 365
# 550 365
# 551 365
# OTHER 151 351
#  DONE: Entirely Processed 2020-11-02
# All Data Opened for 2020-11-04
# 552 365
# 553 365
# 554 365
# 555 365
# 556 365
# 557 365
# 558 365
# 559 365
# 560 365
#  DONE: Entirely Processed 2020-11-04
# All Data Opened for 2020-11-05
# 561 365
# 562 365
# 563 365
# 564 365
# 565 365
# 566 365
# 567 365
# 568 365
# 569 365
#  DONE: Entirely Processed 2020-11-05
# All Data Opened for 2020-11-10
# 570 365
# 571 365
# 572 365
# 573 365
# 574 365
# 575 365
# 576 365
# 577 365
# 578 365
# 364 44 364
# 579 365
#  DONE: Entirely Processed 2020-11-10
# All Data Opened for 2020-11-13
# OTHER 152 358
# 580 365
# 581 365
# 582 365
# 583 365
# 584 365
# 585 365
# 586 365
# 587 365
# 588 365
# 589 365
# 364 45 364
# 590 365
# 591 365
#  DONE: Entirely Processed 2020-11-13
# All Data Opened for 2020-11-17
# 592 365
# 593 365
# 594 365
# 595 365
# 596 365
# 597 365
# 598 365
# 599 365
# 600 365
# OTHER 153 328
# 601 365
#  DONE: Entirely Processed 2020-11-17
# All Data Opened for 2020-11-22
# 364 46 364
# 602 365
# 603 365
# 604 365
# 605 365
# 606 365
# 607 365
# 608 365
# 609 365
#  DONE: Entirely Processed 2020-11-22
# All Data Opened for 2020-11-25
# OTHER 154 320
# 364 47 364
# 610 365
# 611 365
# 612 365
# 613 365
# 614 365
# 615 365
# 616 365
#  DONE: Entirely Processed 2020-11-25
# All Data Opened for 2020-11-28
# 364 48 364
# 617 365
# 618 365
# 619 365
# 620 365
# 621 365
# 622 365
# 623 365
# 624 365
#  DONE: Entirely Processed 2020-11-28
# All Data Opened for 2020-11-30
# 364 49 364
# 625 365
# 626 365
# 627 365
# 628 365
# 629 365
# 630 365
# OTHER 155 312
#  DONE: Entirely Processed 2020-11-30
# All Data Opened for 2020-11-30
# 364 50 364
# 631 365
# 632 365
# 633 365
# 634 365
# 635 365
# 636 365
# OTHER 156 312
#  DONE: Entirely Processed 2020-11-30
# All Data Opened for 2020-12-02
# 637 365
# 638 365
# 639 365
# 640 365
# 641 365
# 642 365
#  DONE: Entirely Processed 2020-12-02
# All Data Opened for 2020-12-05
# 643 365
# 644 365
# 645 365
# 646 365
# 647 365
# 648 365
# 649 365
#  DONE: Entirely Processed 2020-12-05
# All Data Opened for 2020-12-09
# OTHER 157 318
# 650 365
# 651 365
# 652 365
# 653 365
# 654 365
# 655 365
#  DONE: Entirely Processed 2020-12-09
# All Data Opened for 2020-12-13
# 656 365
# 657 365
# 658 365
# 659 365
# 364 51 364
# 660 365
# 661 365
# OTHER 158 346
#  DONE: Entirely Processed 2020-12-13
# All Data Opened for 2020-12-16
# 662 365
# 663 365
# 664 365
# 665 365
# 666 365
# 667 365
# 668 365
#  DONE: Entirely Processed 2020-12-16
# All Data Opened for 2020-12-18
# 669 365
# 670 365
# 671 365
# 672 365
# 673 365
# 674 365
# 675 365
# 676 365
#  DONE: Entirely Processed 2020-12-18
# All Data Opened for 2020-12-20
# 677 365
# 678 365
# 679 365
# 680 365
# 681 365
# 682 365
# 683 365
# 684 365
#  DONE: Entirely Processed 2020-12-20
# All Data Opened for 2020-12-22
# 685 365
# 686 365
# 687 365
# 688 365
# 689 365
# 690 365
# 691 365
# 692 365
# 693 365
# 694 365
#  DONE: Entirely Processed 2020-12-22
# All Data Opened for 2020-12-25
# 695 365
# 696 365
# 697 365
# 698 365
# 699 365
# 700 365
# 701 365
# 702 365
# 703 365
# 704 365
# 705 365
#  DONE: Entirely Processed 2020-12-25
# All Data Opened for 2020-12-27
# 706 365
# 707 365
# 708 365
# 709 365
# 710 365
# 711 365
# 712 365
# 713 365
# 714 365
# 715 365
# OTHER 159 352
#  DONE: Entirely Processed 2020-12-27
# All Data Opened for 2020-12-30
# 716 365
# 717 365
# 718 365
# 719 365
# 720 365
# 721 365
# 722 365
# 723 365
# 724 365
# 725 365
# 726 365
# 364 52 364
# 364 53 364
#  DONE: Entirely Processed 2020-12-30
# All Data Opened for 2020-12-31
# 727 365
# 728 365
# 729 365
# 730 365
# 731 365
# 364 54 364
# 732 365
# 733 365
# 734 365
# 735 365
# 736 365
# 737 365
# 364 55 364
#  DONE: Entirely Processed 2020-12-31

# %%
plt.figure(figsize = (10,15))
for i in orbits:
    plt.plot(i.mean(dim = 'row'))
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ds_list = []
orbit_num = 0

for da in orbits:
    
    ds = da.to_dataset()
    t = ds.time.copy()
    
    # Index
    ds['time'] = np.arange(365)
    ds = ds.rename({'time':'index'})

    #Time
    ds['time'] = (['index'], t.values)

    #Orbit
    ds['orbit'] = orbit_num
    orbit_num += 1

    
    ds_list.append(ds)
ds = xr.concat(ds_list, dim='orbit')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (row: 256, index: 365, orbit: 737)
# Coordinates:
#   * row      (row) float32 0.0 1.0 2.0 3.0 4.0 ... 251.0 252.0 253.0 254.0 255.0
#   * index    (index) int32 0 1 2 3 4 5 6 7 8 ... 357 358 359 360 361 362 363 364
#   * orbit    (orbit) int32 0 1 2 3 4 5 6 7 8 ... 729 730 731 732 733 734 735 736
# Data variables:
#     I_1356   (orbit, index, row) float32 -3.906 -5.498 -3.791 ... -17.68 -13.98
#     time     (orbit, index) datetime64[ns] 2020-01-01T02:37:46.516000 ... 202...

# %%
plt.figure()
ds.I_1356.mean(dim = 'row').plot(vmax=4000)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dsmedian = ds.median(dim='orbit')
ds05 = ds.quantile(0.01, dim='orbit')
ds95 = ds.quantile(0.99, dim='orbit')

plt.figure()
plt.plot(ds.index, ds.I_1356.mean(dim='row').T, 'k-', lw=0.1, alpha=0.4);

plt.plot(dsmedian.I_1356.mean(dim='row'), 'C2-', lw=2)
plt.plot(ds05.I_1356.mean(dim='row'), 'C0-')
plt.plot(ds95.I_1356.mean(dim='row'), 'C1-')
plt.ylim((-100,4000))

plt.title("Unfiltered Orbits for PCA")
plt.xlabel("Time Index")
plt.ylabel("FUV Brightness")

# plt.plot(dsmedian.I_1356 + 3*dsstd.I_1356, 'k-')
# plt.plot(dsmedian.I_1356 - 3*dsstd.I_1356, 'k-')

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
d_rem = ds.I_1356.mean(dim='row')
dmed_rem = dsmedian.I_1356.mean(dim='row')
d = d_rem -dmed_rem 
badness = d.std(dim='index')

plt.figure()
sns.histplot(badness)
# Out:
# C:\Users\pkoll\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Count'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
good = badness < 200

dsgood = ds.where(good, drop=True)

plt.figure()
plt.plot(dsgood.index, dsgood.I_1356.mean(dim='row').T, 'k-', lw=0.5, alpha=0.5);

plt.plot(dsmedian.I_1356.mean(dim='row'), 'C2-', lw=2)
plt.plot(ds05.I_1356.mean(dim='row'), 'C0-')
plt.plot(ds95.I_1356.mean(dim='row'), 'C1-')
plt.ylim((-100,4000))
# Out:
# C:\Users\pkoll\AppData\Local\Temp\ipykernel_14036\259969998.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()
# (-100.0, 4000.0)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# WEIRD OUTLIER DAY
bad = ds.where(ds.I_1356.mean(dim='row') > 10000, drop=True)
bad.time
# Out:
# <xarray.DataArray 'time' (orbit: 4, index: 2)>
# array([[                          'NaT', '2020-11-30T07:14:22.921000000'],
#        ['2020-11-30T07:14:22.921000000',                           'NaT'],
#        [                          'NaT', '2020-11-30T07:14:22.921000000'],
#        ['2020-11-30T07:14:22.921000000',                           'NaT']],
#       dtype='datetime64[ns]')
# Coordinates:
#   * index    (index) int32 127 144
#   * orbit    (orbit) int32 626 627 632 633

# %%
dsday = ds.where(ds.time.dt.date == datetime.date(2020,11,30), drop=True)

# %%
dsday
# Out:
# <xarray.Dataset>
# Dimensions:  (orbit: 12, index: 365, row: 256)
# Coordinates:
#   * row      (row) float32 0.0 1.0 2.0 3.0 4.0 ... 251.0 252.0 253.0 254.0 255.0
#   * index    (index) int32 0 1 2 3 4 5 6 7 8 ... 357 358 359 360 361 362 363 364
#   * orbit    (orbit) int32 624 625 626 627 628 629 630 631 632 633 634 635
# Data variables:
#     I_1356   (orbit, index, row) float32 -4.052 -5.725 -3.831 ... -18.52 -25.27
#     time     (orbit, index) datetime64[ns] 2020-11-30T02:00:22.576000 ... 202...

# %%
### PCA CODE

from sklearn.preprocessing import scale 
from sklearn.linear_model import LinearRegression, Ridge, RidgeCV, Lasso, LassoCV
from sklearn import model_selection
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

X = df_u
y = df_drift_mer


#Train Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

#sc = StandardScaler()
#sc.fit(X_train)
#sc.fit(X_test)

#X_reduced_train = sc.transform(X_train)
#X_reduced_test = sc.transform(X_test)


pca = PCA()
pca.fit(X_train)

X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)

model = LinearRegression(fit_intercept=True)
model.fit(X_train_pca, y_train)

y_pred_test_pca = model.predict(X_test_pca)
y_pred_train_pca = model.predict(X_train_pca)

from sklearn.metrics import r2_score
r2_train = r2_score(y_train, y_pred_train_pca)
r2_test = r2_score(y_test, y_pred_test_pca)
print(r2_train,r2_test)

# %%
var = np.cumsum(np.round(pca.explained_variance_ratio_, decimals = 4)*100)

plt.figure()
plt.plot(var, '-o')
plt.xlabel('Number of Principal Components')
plt.ylabel('Variance')
plt.title('Variance vs Number of Principal Components') 
plt.axvline(8)
plt.show()
